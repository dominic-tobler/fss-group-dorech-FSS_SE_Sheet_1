# %% [markdown]
# # Fundamentals of Software Systems (FSS)
# **Software Evolution – Part 02 Assignment**
#
# ## Submission Guidelines
#
# To correctly complete this assignment you must:
# * Carry out the assignment in a team of 2 to 4 students.
# * Carry out the assignment with your team only. You are allowed to discuss solutions with other teams, but each team should come up its own personal solution. A strict plagiarism policy is going to be applied to all the artifacts submitted for evaluation.
# * As your submission, upload the filled Jupyter Notebook (including outputs) together with the d3 visualization web pages (i.e. upload everything you downloaded including the filled Jupyter Notebook plus your `output.json`)
# * The files must be uploaded to OLAT as a single ZIP (`.zip`) file by Dec 15, 2025 @ 23:55.

# %% [markdown]
# ## Group Members
# * Charlotte Model, 21-717-731
# * Dominic Tobler, 21-705-223
# * Remo Wiget, 21-742-655

# %% [markdown]
# ## Task Context
#
# In this assigment we will be analyzing the _elasticsearch_ project. All following tasks should be done with the subset of commits from tag `v0.90.0` to tag `v1.0.0.RC1`.

# %%
from enum import Enum
from warnings import catch_warnings
import matplotlib.pyplot as plt
import numpy as np
import pydriller

class Modification(Enum):
    ADDED = "Lines added"
    REMOVED = "Lines removed"
    TOTAL = "Lines added + lines removed"
    DIFF = "Lines added - lines removed"


elastic_search_repo = pydriller.Repository("./elasticsearch",
                            from_tag="v0.90.0",
                            to_tag="v1.0.0.RC1")
total_number_of_commits = 0
for commit in elastic_search_repo.traverse_commits():
    total_number_of_commits += 1

print(total_number_of_commits)
# Out:
# 1934

# %% [markdown]
# ## Task 1: Author analysis
#
# In the following, please consider only `java` files.
#
# The first task is to get an overview of the author ownership of the _elasticsearch_ project. In particular, we want to understand who are the main authors in the system between the two considered tags, the authors distribution among files and the files distribution among authors. To this aim, perform the following:
# - create a dictionary (or a list of tuples) with the pairs author => number of modified files
# - create a dictionary (or a list of tuples) with the pairs file => number of authors who modified the file
# - visualize the distribution of authors among files: the visualization should have on the x axis the number of authors per file (from 1 to max), and on the y axis the number of files with the given number of authors (so for example the first bar represent the number of files with single author)
# - visualize the distribution of files among authors: the visualization should have on the x axis the number of files per author (from 1 to max), and on the y axis the number of authors that own the given number of files (so for example the first bar represent the minor contributors, i.e., the number of authors who own 1 file)
#
# Comment the two distribution visualizations.
#
#
#
# Now, let's look at the following 3 packages in more details:
# 1. `src/main/java/org/elasticsearch/search`
# 2. `src/main/java/org/elasticsearch/index`
# 3. `src/main/java/org/elasticsearch/action`
#
# Create a function that, given the path of a package and a modification type (see class Modification above), returns a dictionary of authors => number, where the number counts the total lines added or removed or added+removed or added-removed (depending on the given Modification parameter), for the given package. To compute the value at the package level, you should aggregate the data per file.
#
# Using the function defined above, visualize the author contributions (lines added + lines removed). The visualization should have the author on the x axis, and the total lines on the y axis. Sort the visualization in decreasing amount of contributions, i.e., the main author should be the first.
#
# Compare the visualization for the 3 packages and comment.

# %%
from collections import defaultdict
from tqdm import tqdm

progress = tqdm(unit="commit", total=total_number_of_commits)

authorToModifiedFiles = defaultdict(list)
fileToAuthors = defaultdict(list)
errors = 0

for commit in elastic_search_repo.traverse_commits():
    try:
        commitAuthor = commit.author.name
        files = commit.modified_files
        for file in files:
            fileName = file.filename
            authorToModifiedFiles[commitAuthor].append(fileName)
            fileToAuthors[fileName].append(commitAuthor)
    except ValueError:
        errors += 1
    finally:
        progress.update(1)
# Out:
# 100%|█████████▉| 1933/1934 [00:35<00:00, 62.98commit/s]

# %%
authorToModifiedFilesNum = defaultdict(int)
fileToAuthorsNum = defaultdict(int)

for author, files in authorToModifiedFiles.items():
    authorToModifiedFilesNum[author] = len(set(files))

for file, authors in fileToAuthors.items():
    fileToAuthorsNum[file] = len(set(authors))

# %%
# Visualization
y_counts = np.bincount(list(fileToAuthorsNum.values()))
x_counts = np.arange(len(y_counts))

plt.bar(x_counts[1:], y_counts[1:])       # make plot start at 1
plt.xlabel("#authors per file")
plt.ylabel("#files with specific num of authors")
plt.show()

# %% [markdown]
# This plot visualizes how distributed the file authorship is across the elastic search library. We see that many files have few authors, while few files have a lot of authors.
# From a software engineering perspective, we would expect a file that is maintained by a lower number of authors to yield a better quality due to the sense of responsibility. When a lot of authors work on a file, this responsibility gets diluted, so nobody might feel the need to refactor the code to maintain a certain code quality.
# On the other hand, one could argue, that a single author editing a file points to knowledge about this specific piece of coe being concentrated in the hands of one person, leading to problems when this person leaves the project.

# %%
hist, bin_edges = np.histogram(list(authorToModifiedFilesNum.values()), bins=25)

plt.bar(
    bin_edges[:-1],
    hist,
    width=np.diff(bin_edges),  # widths of bars
    align='edge',
    edgecolor='black')
plt.xlabel("#files per author")
plt.ylabel("#authors with specific num of files")
plt.show()

# %% [markdown]
# This visualization shows the distribution of contributions to the elastic search codebase.
# It is observable that most authors only edited one file, while some authors contributed a lot more.
# From a software engineering perspective, we would expect it to  be desirable, having authors that know about the project and contribute multiple times. Those authors commiting a lot, being responsible for a high proportion of contributions, are important for the project, concentrating a lot of knowledge in specific authors. Then again, the amount of concentration in this project is high, with one author editing over 3'000 files. Would this person leave, a lot of project specific knowledge would be lost. This can impose relevant risks for the long-term survival of the project.

# %%
from collections import defaultdict
import re

def get_auth_to_mod_num(package_path, mod):
    if type(mod) != Modification:
        raise ValueError("Parameter 'mod' must be an instance of Class Modification")
    repo = pydriller.Repository("./elasticsearch", from_tag="v0.90.0", to_tag="v1.0.0.RC1")
    progress = tqdm(unit="commit", total=total_number_of_commits)
    author_to_mod_num = defaultdict(int)
    for commit in repo.traverse_commits():
        author = commit.author.name
        for file in commit.modified_files:
            if (file.new_path != None and (re.search(package_path, file.new_path))) or (file.old_path != None and (re.search(package_path, file.old_path))):
                if mod == Modification.ADDED:
                    author_to_mod_num[author] += file.added_lines
                elif mod == Modification.REMOVED:
                    author_to_mod_num[author] += file.deleted_lines
                elif mod == Modification.TOTAL:
                    author_to_mod_num[author] += file.added_lines + file.deleted_lines
                elif mod == Modification.DIFF:
                    author_to_mod_num[author] += file.added_lines - file.deleted_lines
        progress.update(1)
    return author_to_mod_num

# %%
search_package = get_auth_to_mod_num("src/main/java/org/elasticsearch/search", Modification.TOTAL)
index_package = get_auth_to_mod_num("src/main/java/org/elasticsearch/index", Modification.TOTAL)
action_package = get_auth_to_mod_num("src/main/java/org/elasticsearch/action", Modification.TOTAL)
# Out:
# 100%|██████████| 1934/1934 [00:35<00:00, 54.44commit/s]
# 100%|██████████| 1934/1934 [00:34<00:00, 55.44commit/s]
# 100%|██████████| 1934/1934 [00:37<00:00, 52.19commit/s]

# %%
import pandas as pd
df_search = pd.DataFrame(list(search_package.items()), columns=['author', 'modifications'])
df_search.sort_values(by='modifications', ascending=False, inplace=True)
plt.bar(df_search['author'], df_search['modifications'])
plt.xticks(rotation=90)
plt.xlabel("Author")
plt.ylabel("Total Number of Lines Modified")
plt.title("Author Contributions in the 'Search' Package")
plt.show()

# %%
df_index = pd.DataFrame(list(index_package.items()), columns=['author', 'modifications'])
df_index.sort_values(by='modifications', ascending=False, inplace=True)
plt.bar(df_index['author'], df_index['modifications'])
plt.xticks(rotation=90)
plt.xlabel("Author")
plt.ylabel("Total Number of Lines Modified")
plt.title("Author Contributions in the 'Index' Package")
plt.show()

# %%
df_action = pd.DataFrame(list(action_package.items()), columns=['author', 'modifications'])
df_action.sort_values(by='modifications', ascending=False, inplace=True)
plt.bar(df_action['author'], df_action['modifications'])
plt.xticks(rotation=90)
plt.xlabel("Author")
plt.ylabel("Total Number of Lines Modified")
plt.title("Author Contributions in the 'Action' Package")
plt.show()

# %% [markdown]
# #### Comparing Author Contributions Across the "Search", "Index" and "Action" Packages
# Comparing the three visualizations showing the author contributions in each respective package, we see that the Index package has the greatest number authors; with a total of 30 contributing authors, it has more authors than the Search and Action packages with 20 contributing authors each. Furthermore, the contribution of the individual authors is unbalanced in all three packages. In the Search package, the top most contributing author modified twice as many lines as the second most contributing author; this imbalance is not quite as stark in the Index and Action packages.
# There is also significant overlap in the authors across the three packages: Simon Willnauer, Martijn van Groningen and Shay Banon all appear among the top six most contributing authors in each package.

# %% [markdown]
# ## Task 2: Knowledge loss
#
# We now want to analyze the knowledge loss when the main contributor of the analyzed project would leave. For this we will use the circle packaging layout introduced in the "Code as a Crime Scene" book. This assignment includes the necessary `knowledge_loss.html` file as well as the `d3` folder for all dependencies. You task is to create the `output.json` file according to the specification below. This file can then be visualized with the files provided.
#
# For showing the visualization, once you have the output as `output.json` you should
# * make sure to have the `knowledge_loss.html` file in the same folder
# * start a local HTTP server in the same folder (e.g. with python `python3 -m http.server`) to serve the html file (necessary for d3 to work)
# * open the served `knowledge_loss.html` and look at the visualization
#
# For the package you identify as the worst in terms of knowledge loss, investigate the author contributions using the function defined in the previous exercise and comment how the situation is, e.g. how big the gap between the main author and the second biggest contributor for the selected package is.

# %% [markdown]
# ### Output Format for Visualization
#
# * `root` is always the root of the tree
# * `size` should be the total number of lines of contribution
# * `weight` can be set to the same as `size`
# * `ownership` should be set to the percentage of contributions from the main author (e.g. 0.98 for 98% if contributions coming from the main author)
#
# ```
# {
#   "name": "root",
#   "children": [
#     {
#       "name": "test",
#       "children": [
#         {
#           "name": "benchmarking",
#           "children": [
#             {
#               "author_color": "red",
#               "size": "4005",
#               "name": "t6726-patmat-analysis.scala",
#               "weight": 1.0,
#               "ownership": 0.9,
#               "children": []
#             },
#             {
#               "author_color": "red",
#               "size": "55",
#               "name": "TreeSetIterator.scala",
#               "weight": 0.88,
#               "ownership": 0.9,
#               "children": []
#             }
#           ]
#         }
#       ]
#     }
#   ]
# }
# ```
#
# ### JSON Export
#
# For exporting the data to JSON you can use the following snippet:
#
# ```
# import json
#
# with open("output.json", "w") as file:
#     json.dump(tree, file, indent=4)
# ```

# %%
import json

tree = {
  "name": "root",
  "children": [
    {
      "name": "test",
      "children": [
        {
          "name": "benchmarking",
          "children": [
            {
              "author_color": "red",
              "size": "4005",
              "name": "t6726-patmat-analysis.scala",
              "weight": 1.0,
              "ownership": 0.9,
              "children": []
            },
            {
              "author_color": "red",
              "size": "55",
              "name": "TreeSetIterator.scala",
              "weight": 0.88,
              "ownership": 0.9,
              "children": []
            }
          ]
        }
      ]
    }
  ]
}

with open("output.json", "w") as file:
    json.dump(tree, file, indent=4)

# %%
from collections import defaultdict
from tqdm import tqdm

progress = tqdm(unit="commit", total=total_number_of_commits)

'''
contributions = {new_path: 
                    {"filename": filename,
                     author: loc int, 
                     "loc_total": int}

who is the main contributer??

for all files, for main contributer:
loss_main_conributer = {new_path:
            {
              "author_color": "red",
              "size": loc_total,
              "name": filename,
              "weight": size,
              "ownership": loc / loc_total,
              "children": []
            },
}
'''

contributions = {}
errors = 0
for commit in elastic_search_repo.traverse_commits():
    try:
        commitAuthor = commit.author.name
        files = commit.modified_files
        for file in files:
            filename = file.filename
            if filename.endswith(".java"):
                path = file.new_path or file.old_path
                lines_contribution = (file.added_lines + file.deleted_lines)
                if path not in contributions:
                    contributions[path] = {"filename": filename, "total_loc": 0} 
                if commitAuthor not in contributions[path]:
                    contributions[path][commitAuthor] = 0
                contributions[path]["total_loc"] += lines_contribution
                contributions[path][commitAuthor] += lines_contribution

    
    except ValueError:
        errors += 1
    finally:
        progress.update(1)
    i+=1
# Out:
# 100%|██████████| 1934/1934 [02:24<00:00, 13.37commit/s]

# %%
contributions
# Out:
# {'src/main/java/org/elasticsearch/Version.java': {'filename': 'Version.java',
#   'total_loc': 170,
#   'Shay Banon': 73,
#   'Simon Willnauer': 69,
#   'Alexander Reelsen': 10,
#   'Adrien Grand': 2,
#   'Boaz Leskes': 14,
#   'Kevin Kluge': 2},
#  'src/test/java/org/elasticsearch/test/integration/search/query/SimpleQueryTests.java': {'filename': 'SimpleQueryTests.java',
#   'total_loc': 1739,
#   'Simon Willnauer': 1319,
#   'Martijn van Groningen': 21,
#   'Shay Banon': 302,
#   'Clinton Gormley': 12,
#   'Cédric HOURCADE': 24,
#   'Nik Everett': 32,
#   'uboness': 29},
#  'src/main/java/org/elasticsearch/action/admin/indices/analyze/TransportAnalyzeAction.java': {'filename': 'TransportAnalyzeAction.java',
#   'total_loc': 52,
#   'Simon Willnauer': 49,
#   'Adrien Grand': 3},
#  'src/main/java/org/elasticsearch/index/analysis/NumericTokenizer.java': {'filename': 'NumericTokenizer.java',
#   'total_loc': 85,
#   'Simon Willnauer': 26,
#   'Adrien Grand': 59},
#  'src/main/java/org/elasticsearch/index/mapper/FieldMapper.java': {'filename': 'FieldMapper.java',
#   'total_loc': 72,
#   'Simon Willnauer': 19,
#   'Shay Banon': 4,
#   'Alexander Reelsen': 2,
#   'Adrien Grand': 42,
#   'Boaz Leskes': 2,
#   'Matt Weber': 3},
#  'src/main/java/org/elasticsearch/index/mapper/core/AbstractFieldMapper.java': {'filename': 'AbstractFieldMapper.java',
#   'total_loc': 598,
#   'Simon Willnauer': 45,
#   'Britta Weber': 2,
#   'Shay Banon': 6,
#   'Alexander Reelsen': 4,
#   'Boaz Leskes': 81,
#   'Adrien Grand': 253,
#   'Matt Weber': 18,
#   'Martijn van Groningen': 189},
#  'src/main/java/org/elasticsearch/index/mapper/core/NumberFieldMapper.java': {'filename': 'NumberFieldMapper.java',
#   'total_loc': 395,
#   'Simon Willnauer': 22,
#   'Shay Banon': 33,
#   'Adrien Grand': 215,
#   'Boaz Leskes': 23,
#   'Matt Weber': 61,
#   'Martijn van Groningen': 11,
#   'markharwood': 30},
#  'src/test/java/org/elasticsearch/test/integration/indices/analyze/AnalyzeActionTests.java': {'filename': 'AnalyzeActionTests.java',
#   'total_loc': 121,
#   'Simon Willnauer': 121},
#  'src/main/java/org/elasticsearch/common/xcontent/support/XContentMapValues.java': {'filename': 'XContentMapValues.java',
#   'total_loc': 122,
#   'Alexander Reelsen': 3,
#   'Boaz Leskes': 63,
#   'Adrien Grand': 9,
#   'Simon Willnauer': 18,
#   'Rob Cherry': 29},
#  'src/test/java/org/elasticsearch/test/integration/search/geo/GeoShapeIntegrationTests.java': {'filename': 'GeoShapeIntegrationTests.java',
#   'total_loc': 388,
#   'Alexander Reelsen': 50,
#   'Simon Willnauer': 162,
#   'Florian Schilling': 99,
#   'Shay Banon': 77},
#  'src/test/java/org/elasticsearch/test/unit/common/xcontent/support/XContentMapValuesTests.java': {'filename': 'XContentMapValuesTests.java',
#   'total_loc': 197,
#   'Alexander Reelsen': 16,
#   'Boaz Leskes': 178,
#   'Simon Willnauer': 3},
#  'src/main/java/org/elasticsearch/index/get/ShardGetService.java': {'filename': 'ShardGetService.java',
#   'total_loc': 311,
#   'Alexander Reelsen': 27,
#   'Igor Motov': 37,
#   'Adrien Grand': 13,
#   'Martijn van Groningen': 62,
#   'Boaz Leskes': 140,
#   'Simon Willnauer': 32},
#  'src/main/java/org/elasticsearch/index/mapper/internal/SourceFieldMapper.java': {'filename': 'SourceFieldMapper.java',
#   'total_loc': 179,
#   'Alexander Reelsen': 8,
#   'Shay Banon': 85,
#   'Boaz Leskes': 47,
#   'Adrien Grand': 21,
#   'Simon Willnauer': 18},
#  'src/test/java/org/elasticsearch/test/integration/get/GetActionTests.java': {'filename': 'GetActionTests.java',
#   'total_loc': 696,
#   'Alexander Reelsen': 114,
#   'Igor Motov': 79,
#   'Shay Banon': 64,
#   'Simon Willnauer': 170,
#   'Martijn van Groningen': 204,
#   'Boaz Leskes': 65},
#  'src/test/java/org/elasticsearch/test/integration/gateway/local/SimpleRecoveryLocalGatewayTests.java': {'filename': 'SimpleRecoveryLocalGatewayTests.java',
#   'total_loc': 191,
#   'Igor Motov': 12,
#   'Simon Willnauer': 124,
#   'Shay Banon': 5,
#   'Alexander Reelsen': 50},
#  'src/main/java/org/elasticsearch/action/ShardOperationFailedException.java': {'filename': 'ShardOperationFailedException.java',
#   'total_loc': 20,
#   'Martijn van Groningen': 6,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/action/deletebyquery/DeleteByQueryResponse.java': {'filename': 'DeleteByQueryResponse.java',
#   'total_loc': 35,
#   'Martijn van Groningen': 21,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/action/deletebyquery/IndexDeleteByQueryResponse.java': {'filename': 'IndexDeleteByQueryResponse.java',
#   'total_loc': 38,
#   'Martijn van Groningen': 24,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/action/deletebyquery/TransportIndexDeleteByQueryAction.java': {'filename': 'TransportIndexDeleteByQueryAction.java',
#   'total_loc': 27,
#   'Martijn van Groningen': 13,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/action/support/DefaultShardOperationFailedException.java': {'filename': 'DefaultShardOperationFailedException.java',
#   'total_loc': 37,
#   'Martijn van Groningen': 17,
#   'Simon Willnauer': 20},
#  'src/main/java/org/elasticsearch/rest/action/deletebyquery/RestDeleteByQueryAction.java': {'filename': 'RestDeleteByQueryAction.java',
#   'total_loc': 50,
#   'Martijn van Groningen': 25,
#   'David Pilato': 7,
#   'Simon Willnauer': 14,
#   'Lee Hinman': 4},
#  'src/test/java/org/elasticsearch/test/integration/deleteByQuery/DeleteByQueryTests.java': {'filename': 'DeleteByQueryTests.java',
#   'total_loc': 89,
#   'Martijn van Groningen': 18,
#   'Simon Willnauer': 71},
#  'src/main/java/org/elasticsearch/index/fielddata/fieldcomparator/GeoDistanceComparator.java': {'filename': 'GeoDistanceComparator.java',
#   'total_loc': 132,
#   'Martijn van Groningen': 34,
#   'Simon Willnauer': 98},
#  'src/main/java/org/elasticsearch/search/sort/GeoDistanceSortParser.java': {'filename': 'GeoDistanceSortParser.java',
#   'total_loc': 131,
#   'Martijn van Groningen': 71,
#   'Florian Schilling': 26,
#   'Luca Cavanna': 8,
#   'Clinton Gormley': 2,
#   'Simon Willnauer': 24},
#  'src/test/java/org/elasticsearch/test/integration/search/geo/GeoDistanceTests.java': {'filename': 'GeoDistanceTests.java',
#   'total_loc': 650,
#   'Martijn van Groningen': 248,
#   'Simon Willnauer': 185,
#   'Florian Schilling': 54,
#   'Britta Weber': 163},
#  'src/main/java/org/elasticsearch/index/analysis/HunspellTokenFilterFactory.java': {'filename': 'HunspellTokenFilterFactory.java',
#   'total_loc': 48,
#   'uboness': 7,
#   'Simon Willnauer': 29,
#   'Lukas Vlcek': 12},
#  'src/main/java/org/elasticsearch/index/search/child/ChildrenQuery.java': {'filename': 'ChildrenQuery.java',
#   'total_loc': 649,
#   'Martijn van Groningen': 545,
#   'Simon Willnauer': 29,
#   'Shay Banon': 55,
#   'Adrien Grand': 16,
#   'Josh Canfield': 2,
#   'Andrew Raines': 2},
#  'src/main/java/org/elasticsearch/index/search/child/ParentQuery.java': {'filename': 'ParentQuery.java',
#   'total_loc': 285,
#   'Martijn van Groningen': 218,
#   'Simon Willnauer': 30,
#   'Shay Banon': 27,
#   'Adrien Grand': 10},
#  'src/main/java/org/elasticsearch/index/search/child/TopChildrenQuery.java': {'filename': 'TopChildrenQuery.java',
#   'total_loc': 442,
#   'Martijn van Groningen': 249,
#   'Simon Willnauer': 109,
#   'Shay Banon': 67,
#   'Adrien Grand': 17},
#  'src/test/java/org/elasticsearch/test/unit/index/analysis/HunspellTokenFilterFactoryTests.java': {'filename': 'HunspellTokenFilterFactoryTests.java',
#   'total_loc': 126,
#   'uboness': 66,
#   'Simon Willnauer': 17,
#   'Lukas Vlcek': 43},
#  'src/main/java/org/elasticsearch/cluster/routing/allocation/allocator/BalancedShardsAllocator.java': {'filename': 'BalancedShardsAllocator.java',
#   'total_loc': 906,
#   'Simon Willnauer': 787,
#   'Shay Banon': 95,
#   'Igor Motov': 6,
#   'Sebastian Geidies': 18},
#  'src/test/java/org/elasticsearch/test/unit/cluster/routing/allocation/BalanceConfigurationTests.java': {'filename': 'BalanceConfigurationTests.java',
#   'total_loc': 255,
#   'Simon Willnauer': 219,
#   'Lee Hinman': 36},
#  'src/test/java/org/elasticsearch/test/hamcrest/ElasticsearchAssertions.java': {'filename': 'ElasticsearchAssertions.java',
#   'total_loc': 491,
#   'Alexander Reelsen': 91,
#   'Simon Willnauer': 140,
#   'Matt Weber': 10,
#   'Boaz Leskes': 143,
#   'David Pilato': 2,
#   'Nik Everett': 25,
#   'Britta Weber': 9,
#   'Luca Cavanna': 63,
#   'Martijn van Groningen': 8},
#  'src/test/java/org/elasticsearch/test/hamcrest/ElasticsearchMatchers.java': {'filename': 'ElasticsearchMatchers.java',
#   'total_loc': 134,
#   'Alexander Reelsen': 96,
#   'Simon Willnauer': 16,
#   'Luca Cavanna': 22},
#  'src/test/java/org/elasticsearch/test/integration/search/geo/GeoFilterTests.java': {'filename': 'GeoFilterTests.java',
#   'total_loc': 725,
#   'Alexander Reelsen': 33,
#   'Simon Willnauer': 104,
#   'Florian Schilling': 274,
#   'Shay Banon': 314},
#  'src/test/java/org/elasticsearch/test/integration/search/highlight/HighlighterSearchTests.java': {'filename': 'HighlighterSearchTests.java',
#   'total_loc': 1612,
#   'Alexander Reelsen': 11,
#   'Simon Willnauer': 1263,
#   'Martijn van Groningen': 57,
#   'Adrien Grand': 255,
#   'Lukas Vlcek': 26},
#  'src/main/java/org/elasticsearch/action/admin/cluster/health/ClusterHealthRequestBuilder.java': {'filename': 'ClusterHealthRequestBuilder.java',
#   'total_loc': 19,
#   'Igor Motov': 5,
#   'Simon Willnauer': 14},
#  'src/test/java/org/elasticsearch/test/integration/cluster/SimpleDataNodesTests.java': {'filename': 'SimpleDataNodesTests.java',
#   'total_loc': 10,
#   'Igor Motov': 4,
#   'Simon Willnauer': 6},
#  'src/main/java/org/elasticsearch/index/query/FuzzyQueryBuilder.java': {'filename': 'FuzzyQueryBuilder.java',
#   'total_loc': 49,
#   'Anton Hägerstrand': 2,
#   'Martijn van Groningen': 15,
#   'Simon Willnauer': 32},
#  'src/main/java/org/elasticsearch/index/query/MultiTermQueryBuilder.java': {'filename': 'MultiTermQueryBuilder.java',
#   'total_loc': 40,
#   'Anton Hägerstrand': 5,
#   'Alexander Reelsen': 21,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/index/query/PrefixQueryBuilder.java': {'filename': 'PrefixQueryBuilder.java',
#   'total_loc': 31,
#   'Anton Hägerstrand': 2,
#   'Martijn van Groningen': 15,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/index/query/QueryBuilders.java': {'filename': 'QueryBuilders.java',
#   'total_loc': 273,
#   'Anton Hägerstrand': 14,
#   'Derek McNeil': 22,
#   'Martijn van Groningen': 10,
#   'Florian Schilling': 12,
#   'Britta Weber': 69,
#   'uboness': 2,
#   'Luca Cavanna': 15,
#   'Lee Hinman': 115,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/index/query/RangeQueryBuilder.java': {'filename': 'RangeQueryBuilder.java',
#   'total_loc': 29,
#   'Anton Hägerstrand': 2,
#   'Martijn van Groningen': 13,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/index/query/SpanMultiTermQueryBuilder.java': {'filename': 'SpanMultiTermQueryBuilder.java',
#   'total_loc': 59,
#   'Anton Hägerstrand': 24,
#   'Alexander Reelsen': 21,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/index/query/SpanMultiTermQueryParser.java': {'filename': 'SpanMultiTermQueryParser.java',
#   'total_loc': 185,
#   'Anton Hägerstrand': 82,
#   'Alexander Reelsen': 89,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/index/query/WildcardQueryBuilder.java': {'filename': 'WildcardQueryBuilder.java',
#   'total_loc': 31,
#   'Anton Hägerstrand': 2,
#   'Martijn van Groningen': 15,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/indices/query/IndicesQueriesModule.java': {'filename': 'IndicesQueriesModule.java',
#   'total_loc': 25,
#   'Anton Hägerstrand': 2,
#   'Alexander Reelsen': 1,
#   'Simon Willnauer': 15,
#   'Florian Schilling': 1,
#   'Britta Weber': 2,
#   'Shay Banon': 2,
#   'Lee Hinman': 2},
#  'src/test/java/org/elasticsearch/test/unit/index/query/SimpleIndexQueryParserTests.java': {'filename': 'SimpleIndexQueryParserTests.java',
#   'total_loc': 444,
#   'Anton Hägerstrand': 54,
#   'Alexander Reelsen': 122,
#   'Derek McNeil': 38,
#   'Simon Willnauer': 54,
#   'Matt Weber': 39,
#   'Cédric HOURCADE': 34,
#   'Shay Banon': 56,
#   'Britta Weber': 47},
#  'src/main/java/org/elasticsearch/common/lucene/search/XBooleanFilter.java': {'filename': 'XBooleanFilter.java',
#   'total_loc': 196,
#   'Martijn van Groningen': 196},
#  'src/main/java/org/elasticsearch/common/network/NetworkService.java': {'filename': 'NetworkService.java',
#   'total_loc': 31,
#   'Igor Motov': 8,
#   'Simon Willnauer': 23},
#  'src/main/java/org/elasticsearch/common/network/NetworkUtils.java': {'filename': 'NetworkUtils.java',
#   'total_loc': 64,
#   'Igor Motov': 19,
#   'Adrien Grand': 3,
#   'Simon Willnauer': 18,
#   'Shay Banon': 24},
#  'src/main/java/org/elasticsearch/index/fielddata/fieldcomparator/BytesRefOrdValComparator.java': {'filename': 'BytesRefOrdValComparator.java',
#   'total_loc': 537,
#   'Simon Willnauer': 95,
#   'Adrien Grand': 442},
#  'src/test/java/org/elasticsearch/test/integration/search/sort/SimpleSortTests.java': {'filename': 'SimpleSortTests.java',
#   'total_loc': 1137,
#   'Simon Willnauer': 915,
#   'Florian Schilling': 27,
#   'Luca Cavanna': 53,
#   'Britta Weber': 44,
#   'Adrien Grand': 98},
#  'src/main/java/org/elasticsearch/rest/action/main/RestMainAction.java': {'filename': 'RestMainAction.java',
#   'total_loc': 73,
#   'Simon Willnauer': 25,
#   'Shay Banon': 29,
#   'Benjamin Devèze': 5,
#   'Lee Hinman': 10,
#   'Benjamin Devèze': 2,
#   'Alexander Reelsen': 2},
#  'src/main/java/org/elasticsearch/index/query/TermsQueryBuilder.java': {'filename': 'TermsQueryBuilder.java',
#   'total_loc': 41,
#   'Derek McNeil': 11,
#   'Martijn van Groningen': 13,
#   'Simon Willnauer': 17},
#  'src/main/java/org/elasticsearch/action/get/GetResponse.java': {'filename': 'GetResponse.java',
#   'total_loc': 26,
#   'Shay Banon': 8,
#   'Simon Willnauer': 18},
#  'src/main/java/org/elasticsearch/rest/action/RestActionModule.java': {'filename': 'RestActionModule.java',
#   'total_loc': 143,
#   'Shay Banon': 7,
#   'Martijn van Groningen': 26,
#   'Britta Weber': 2,
#   'Andrew Raines': 38,
#   'Alexander Reelsen': 25,
#   'Lee Hinman': 10,
#   'Boaz Leskes': 6,
#   'Igor Motov': 15,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/rest/action/admin/indices/analyze/RestAnalyzeAction.java': {'filename': 'RestAnalyzeAction.java',
#   'total_loc': 23,
#   'Shay Banon': 2,
#   'Simon Willnauer': 21},
#  'src/main/java/org/elasticsearch/rest/action/get/RestGetSourceAction.java': {'filename': 'RestGetSourceAction.java',
#   'total_loc': 146,
#   'Shay Banon': 88,
#   'Boaz Leskes': 44,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/rest/action/get/RestHeadAction.java': {'filename': 'RestHeadAction.java',
#   'total_loc': 17,
#   'Shay Banon': 1,
#   'Luca Cavanna': 2,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/rest/action/support/RestXContentBuilder.java': {'filename': 'RestXContentBuilder.java',
#   'total_loc': 147,
#   'Shay Banon': 124,
#   'Luca Cavanna': 5,
#   'Simon Willnauer': 14,
#   'Alexander Reelsen': 4},
#  'src/main/java/org/apache/lucene/analysis/miscellaneous/KeywordRepeatFilter.java': {'filename': 'KeywordRepeatFilter.java',
#   'total_loc': 71,
#   'Simon Willnauer': 71},
#  'src/main/java/org/apache/lucene/analysis/miscellaneous/XStemmerOverrideFilter.java': {'filename': 'XStemmerOverrideFilter.java',
#   'total_loc': 169,
#   'Simon Willnauer': 169},
#  'src/main/java/org/apache/lucene/index/TrackingConcurrentMergeScheduler.java': {'filename': 'TrackingConcurrentMergeScheduler.java',
#   'total_loc': 56,
#   'Simon Willnauer': 21,
#   'Shay Banon': 35},
#  'src/main/java/org/apache/lucene/index/TrackingSerialMergeScheduler.java': {'filename': 'TrackingSerialMergeScheduler.java',
#   'total_loc': 53,
#   'Simon Willnauer': 21,
#   'Shay Banon': 32},
#  'src/main/java/org/apache/lucene/search/vectorhighlight/XSimpleFragListBuilder.java': {'filename': 'XSimpleFragListBuilder.java',
#   'total_loc': 254,
#   'Simon Willnauer': 211,
#   'Adrien Grand': 43},
#  'src/main/java/org/elasticsearch/common/lucene/Lucene.java': {'filename': 'Lucene.java',
#   'total_loc': 74,
#   'Simon Willnauer': 59,
#   'Shay Banon': 8,
#   'Adrien Grand': 7},
#  'src/main/java/org/elasticsearch/common/lucene/docset/AllDocIdSet.java': {'filename': 'AllDocIdSet.java',
#   'total_loc': 20,
#   'Simon Willnauer': 20},
#  'src/main/java/org/elasticsearch/common/lucene/docset/AndDocIdSet.java': {'filename': 'AndDocIdSet.java',
#   'total_loc': 24,
#   'Simon Willnauer': 24},
#  'src/main/java/org/elasticsearch/common/lucene/docset/BitsDocIdSetIterator.java': {'filename': 'BitsDocIdSetIterator.java',
#   'total_loc': 19,
#   'Simon Willnauer': 19},
#  'src/main/java/org/elasticsearch/common/lucene/docset/MatchDocIdSet.java': {'filename': 'MatchDocIdSet.java',
#   'total_loc': 97,
#   'Simon Willnauer': 24,
#   'Martijn van Groningen': 73},
#  'src/main/java/org/elasticsearch/common/lucene/docset/NotDocIdSet.java': {'filename': 'NotDocIdSet.java',
#   'total_loc': 32,
#   'Simon Willnauer': 32},
#  'src/main/java/org/elasticsearch/common/lucene/docset/OrDocIdSet.java': {'filename': 'OrDocIdSet.java',
#   'total_loc': 23,
#   'Simon Willnauer': 23},
#  'src/main/java/org/elasticsearch/common/lucene/search/EmptyScorer.java': {'filename': 'EmptyScorer.java',
#   'total_loc': 37,
#   'Simon Willnauer': 24,
#   'Adrien Grand': 13},
#  'src/main/java/org/elasticsearch/common/lucene/search/function/FiltersFunctionScoreQuery.java': {'filename': 'FiltersFunctionScoreQuery.java',
#   'total_loc': 308,
#   'Simon Willnauer': 24,
#   'Britta Weber': 255,
#   'Shay Banon': 19,
#   'Adrien Grand': 2,
#   'Richard Boulton': 8},
#  'src/main/java/org/elasticsearch/common/lucene/search/function/FunctionScoreQuery.java': {'filename': 'FunctionScoreQuery.java',
#   'total_loc': 126,
#   'Simon Willnauer': 26,
#   'Britta Weber': 94,
#   'Shay Banon': 4,
#   'Adrien Grand': 2},
#  'src/main/java/org/elasticsearch/index/analysis/BrazilianStemTokenFilterFactory.java': {'filename': 'BrazilianStemTokenFilterFactory.java',
#   'total_loc': 23,
#   'Simon Willnauer': 23},
#  'src/main/java/org/elasticsearch/index/analysis/DutchStemTokenFilterFactory.java': {'filename': 'DutchStemTokenFilterFactory.java',
#   'total_loc': 18,
#   'Simon Willnauer': 18},
#  'src/main/java/org/elasticsearch/index/analysis/FrenchStemTokenFilterFactory.java': {'filename': 'FrenchStemTokenFilterFactory.java',
#   'total_loc': 20,
#   'Simon Willnauer': 20},
#  'src/main/java/org/elasticsearch/index/analysis/GermanStemTokenFilterFactory.java': {'filename': 'GermanStemTokenFilterFactory.java',
#   'total_loc': 18,
#   'Simon Willnauer': 18},
#  'src/main/java/org/elasticsearch/index/analysis/KeywordMarkerTokenFilterFactory.java': {'filename': 'KeywordMarkerTokenFilterFactory.java',
#   'total_loc': 26,
#   'Simon Willnauer': 26},
#  'src/main/java/org/elasticsearch/index/analysis/PatternTokenizerFactory.java': {'filename': 'PatternTokenizerFactory.java',
#   'total_loc': 26,
#   'Simon Willnauer': 26},
#  'src/main/java/org/elasticsearch/index/analysis/StemmerOverrideTokenFilterFactory.java': {'filename': 'StemmerOverrideTokenFilterFactory.java',
#   'total_loc': 28,
#   'Simon Willnauer': 28},
#  'src/main/java/org/elasticsearch/index/deletionpolicy/AbstractESDeletionPolicy.java': {'filename': 'AbstractESDeletionPolicy.java',
#   'total_loc': 86,
#   'Simon Willnauer': 86},
#  'src/main/java/org/elasticsearch/index/deletionpolicy/KeepLastNDeletionPolicy.java': {'filename': 'KeepLastNDeletionPolicy.java',
#   'total_loc': 16,
#   'Simon Willnauer': 16},
#  'src/main/java/org/elasticsearch/index/deletionpolicy/KeepOnlyLastDeletionPolicy.java': {'filename': 'KeepOnlyLastDeletionPolicy.java',
#   'total_loc': 18,
#   'Simon Willnauer': 18},
#  'src/main/java/org/elasticsearch/index/deletionpolicy/SnapshotDeletionPolicy.java': {'filename': 'SnapshotDeletionPolicy.java',
#   'total_loc': 36,
#   'Simon Willnauer': 36},
#  'src/main/java/org/elasticsearch/index/engine/robin/RobinEngine.java': {'filename': 'RobinEngine.java',
#   'total_loc': 878,
#   'Simon Willnauer': 312,
#   'Shay Banon': 210,
#   'Adrien Grand': 90,
#   'Boaz Leskes': 227,
#   'Martijn van Groningen': 33,
#   'Lee Hinman': 6},
#  'src/main/java/org/elasticsearch/index/merge/policy/LogByteSizeMergePolicyProvider.java': {'filename': 'LogByteSizeMergePolicyProvider.java',
#   'total_loc': 52,
#   'Simon Willnauer': 52},
#  'src/main/java/org/elasticsearch/index/merge/policy/LogDocMergePolicyProvider.java': {'filename': 'LogDocMergePolicyProvider.java',
#   'total_loc': 50,
#   'Simon Willnauer': 50},
#  'src/main/java/org/elasticsearch/index/merge/policy/TieredMergePolicyProvider.java': {'filename': 'TieredMergePolicyProvider.java',
#   'total_loc': 54,
#   'Simon Willnauer': 54},
#  'src/main/java/org/elasticsearch/index/search/nested/IncludeNestedDocsQuery.java': {'filename': 'IncludeNestedDocsQuery.java',
#   'total_loc': 28,
#   'Simon Willnauer': 24,
#   'Martijn van Groningen': 4},
#  'src/main/java/org/elasticsearch/indices/analysis/IndicesAnalysisService.java': {'filename': 'IndicesAnalysisService.java',
#   'total_loc': 770,
#   'Simon Willnauer': 42,
#   'Britta Weber': 14,
#   'Cédric HOURCADE': 14,
#   'Alexander Reelsen': 700},
#  'src/main/java/org/elasticsearch/search/highlight/HighlightPhase.java': {'filename': 'HighlightPhase.java',
#   'total_loc': 350,
#   'Simon Willnauer': 28,
#   'Alexander Reelsen': 283,
#   'Nik Everett': 9,
#   'Luca Cavanna': 22,
#   'Martijn van Groningen': 8},
#  'src/main/java/org/elasticsearch/search/rescore/QueryRescorer.java': {'filename': 'QueryRescorer.java',
#   'total_loc': 251,
#   'Simon Willnauer': 54,
#   'Cédric HOURCADE': 108,
#   'Nik Everett': 5,
#   'Igor Motov': 84},
#  'src/test/java/org/elasticsearch/test/integration/indices/stats/SimpleIndexStatsTests.java': {'filename': 'SimpleIndexStatsTests.java',
#   'total_loc': 348,
#   'Simon Willnauer': 142,
#   'Shay Banon': 199,
#   'Alexander Reelsen': 7},
#  'src/test/java/org/elasticsearch/test/unit/index/search/geo/GeoUtilsTests.java': {'filename': 'GeoUtilsTests.java',
#   'total_loc': 19,
#   'Simon Willnauer': 19},
#  'src/main/java/org/elasticsearch/index/query/GeoShapeFilterParser.java': {'filename': 'GeoShapeFilterParser.java',
#   'total_loc': 38,
#   'Simon Willnauer': 17,
#   'Florian Schilling': 7,
#   'Martijn van Groningen': 14},
#  'src/main/java/org/elasticsearch/index/query/GeoShapeQueryParser.java': {'filename': 'GeoShapeQueryParser.java',
#   'total_loc': 54,
#   'Simon Willnauer': 21,
#   'Florian Schilling': 15,
#   'Martijn van Groningen': 18},
#  'src/main/java/org/elasticsearch/cluster/metadata/MetaDataDeleteIndexService.java': {'filename': 'MetaDataDeleteIndexService.java',
#   'total_loc': 215,
#   'uboness': 2,
#   'Shay Banon': 188,
#   'Simon Willnauer': 25},
#  'src/main/java/org/elasticsearch/search/highlight/vectorhighlight/FragmentBuilderHelper.java': {'filename': 'FragmentBuilderHelper.java',
#   'total_loc': 182,
#   'Simon Willnauer': 150,
#   'Adrien Grand': 32},
#  'src/main/java/org/elasticsearch/search/highlight/vectorhighlight/SourceScoreOrderFragmentsBuilder.java': {'filename': 'SourceScoreOrderFragmentsBuilder.java',
#   'total_loc': 79,
#   'Simon Willnauer': 60,
#   'Adrien Grand': 19},
#  'src/main/java/org/elasticsearch/search/highlight/vectorhighlight/SourceSimpleFragmentsBuilder.java': {'filename': 'SourceSimpleFragmentsBuilder.java',
#   'total_loc': 43,
#   'Simon Willnauer': 43},
#  'src/main/java/org/elasticsearch/indices/analysis/HunspellService.java': {'filename': 'HunspellService.java',
#   'total_loc': 53,
#   'uboness': 3,
#   'Simon Willnauer': 40,
#   'Lukas Vlcek': 10},
#  'src/test/java/org/elasticsearch/test/integration/indices/analyze/HunspellServiceTests.java': {'filename': 'HunspellServiceTests.java',
#   'total_loc': 27,
#   'uboness': 12,
#   'Simon Willnauer': 15},
#  'src/main/java/org/elasticsearch/index/query/SpanTermQueryParser.java': {'filename': 'SpanTermQueryParser.java',
#   'total_loc': 24,
#   'Simon Willnauer': 16,
#   'Martijn van Groningen': 8},
#  'src/main/java/org/elasticsearch/rest/action/search/RestSearchAction.java': {'filename': 'RestSearchAction.java',
#   'total_loc': 56,
#   'Florian Schilling': 7,
#   'Boaz Leskes': 10,
#   'David Pilato': 11,
#   'Martijn van Groningen': 6,
#   'Simon Willnauer': 22},
#  'src/main/java/org/elasticsearch/index/analysis/AbstractTokenFilterFactory.java': {'filename': 'AbstractTokenFilterFactory.java',
#   'total_loc': 18,
#   'Simon Willnauer': 18},
#  'src/main/java/org/elasticsearch/index/analysis/AbstractTokenizerFactory.java': {'filename': 'AbstractTokenizerFactory.java',
#   'total_loc': 19,
#   'Simon Willnauer': 19},
#  'src/main/java/org/apache/lucene/store/RateLimitedFSDirectory.java': {'filename': 'RateLimitedFSDirectory.java',
#   'total_loc': 128,
#   'Igor Motov': 9,
#   'Simon Willnauer': 112,
#   'Shay Banon': 7},
#  'src/main/java/org/apache/lucene/store/StoreUtils.java': {'filename': 'StoreUtils.java',
#   'total_loc': 58,
#   'Igor Motov': 44,
#   'Simon Willnauer': 14},
#  'src/main/java/org/apache/lucene/store/bytebuffer/ByteBufferDirectory.java': {'filename': 'ByteBufferDirectory.java',
#   'total_loc': 29,
#   'Igor Motov': 5,
#   'Simon Willnauer': 24},
#  'src/main/java/org/elasticsearch/index/store/Store.java': {'filename': 'Store.java',
#   'total_loc': 175,
#   'Igor Motov': 5,
#   'Simon Willnauer': 88,
#   'Shay Banon': 82},
#  'src/main/java/org/elasticsearch/index/store/distributor/AbstractDistributor.java': {'filename': 'AbstractDistributor.java',
#   'total_loc': 36,
#   'Igor Motov': 8,
#   'Simon Willnauer': 28},
#  'src/main/java/org/elasticsearch/index/store/distributor/LeastUsedDistributor.java': {'filename': 'LeastUsedDistributor.java',
#   'total_loc': 19,
#   'Igor Motov': 5,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/index/store/distributor/RandomWeightedDistributor.java': {'filename': 'RandomWeightedDistributor.java',
#   'total_loc': 20,
#   'Igor Motov': 6,
#   'Simon Willnauer': 14},
#  'src/test/java/org/elasticsearch/test/integration/indices/store/SimpleDistributorTests.java': {'filename': 'SimpleDistributorTests.java',
#   'total_loc': 189,
#   'Igor Motov': 121,
#   'Simon Willnauer': 50,
#   'Shay Banon': 18},
#  'src/test/java/org/elasticsearch/test/integration/indices/store/StrictDistributor.java': {'filename': 'StrictDistributor.java',
#   'total_loc': 6,
#   'Igor Motov': 6},
#  'src/main/java/org/elasticsearch/common/collect/XMaps.java': {'filename': 'XMaps.java',
#   'total_loc': 206,
#   'Simon Willnauer': 92,
#   'Martijn van Groningen': 114},
#  'src/main/java/org/elasticsearch/search/controller/SearchPhaseController.java': {'filename': 'SearchPhaseController.java',
#   'total_loc': 416,
#   'Simon Willnauer': 56,
#   'Shay Banon': 294,
#   'Martijn van Groningen': 50,
#   'uboness': 16},
#  'src/main/java/org/elasticsearch/search/dfs/AggregatedDfs.java': {'filename': 'AggregatedDfs.java',
#   'total_loc': 115,
#   'Simon Willnauer': 68,
#   'Igor Motov': 4,
#   'Martijn van Groningen': 43},
#  'src/main/java/org/elasticsearch/search/dfs/DfsPhase.java': {'filename': 'DfsPhase.java',
#   'total_loc': 128,
#   'Simon Willnauer': 36,
#   'Shay Banon': 9,
#   'Martijn van Groningen': 81,
#   'Adrien Grand': 2},
#  'src/main/java/org/elasticsearch/search/dfs/DfsSearchResult.java': {'filename': 'DfsSearchResult.java',
#   'total_loc': 221,
#   'Simon Willnauer': 177,
#   'Martijn van Groningen': 44},
#  'src/main/java/org/elasticsearch/cluster/routing/IndexRoutingTable.java': {'filename': 'IndexRoutingTable.java',
#   'total_loc': 152,
#   'Shay Banon': 73,
#   'Igor Motov': 31,
#   'Boaz Leskes': 28,
#   'Simon Willnauer': 20},
#  'src/main/java/org/elasticsearch/cluster/routing/RoutingNodes.java': {'filename': 'RoutingNodes.java',
#   'total_loc': 1120,
#   'Shay Banon': 39,
#   'Martijn van Groningen': 20,
#   'Sebastian Geidies': 319,
#   'Simon Willnauer': 742},
#  'src/main/java/org/elasticsearch/cluster/routing/RoutingTable.java': {'filename': 'RoutingTable.java',
#   'total_loc': 53,
#   'Shay Banon': 25,
#   'Igor Motov': 14,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/cluster/routing/allocation/command/AllocateAllocationCommand.java': {'filename': 'AllocateAllocationCommand.java',
#   'total_loc': 62,
#   'Shay Banon': 20,
#   'Sebastian Geidies': 2,
#   'Simon Willnauer': 40},
#  'src/test/java/org/elasticsearch/test/integration/cluster/allocation/ClusterRerouteTests.java': {'filename': 'ClusterRerouteTests.java',
#   'total_loc': 57,
#   'Shay Banon': 45,
#   'Igor Motov': 3,
#   'Simon Willnauer': 9},
#  'src/main/java/org/elasticsearch/common/bytes/HashedBytesArray.java': {'filename': 'HashedBytesArray.java',
#   'total_loc': 41,
#   'Shay Banon': 15,
#   'Simon Willnauer': 26},
#  'src/main/java/org/elasticsearch/action/bulk/BulkItemRequest.java': {'filename': 'BulkItemRequest.java',
#   'total_loc': 19,
#   'Martijn van Groningen': 5,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/action/bulk/BulkItemResponse.java': {'filename': 'BulkItemResponse.java',
#   'total_loc': 75,
#   'Martijn van Groningen': 15,
#   'Shay Banon': 46,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/action/bulk/BulkRequest.java': {'filename': 'BulkRequest.java',
#   'total_loc': 169,
#   'Martijn van Groningen': 60,
#   'Boaz Leskes': 5,
#   'Luca Cavanna': 25,
#   'Shay Banon': 55,
#   'Simon Willnauer': 24},
#  'src/main/java/org/elasticsearch/action/bulk/BulkRequestBuilder.java': {'filename': 'BulkRequestBuilder.java',
#   'total_loc': 52,
#   'Martijn van Groningen': 20,
#   'Shay Banon': 18,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/action/bulk/BulkShardRequest.java': {'filename': 'BulkShardRequest.java',
#   'total_loc': 21,
#   'Martijn van Groningen': 7,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/action/bulk/TransportBulkAction.java': {'filename': 'TransportBulkAction.java',
#   'total_loc': 92,
#   'Martijn van Groningen': 27,
#   'Boaz Leskes': 42,
#   'Shay Banon': 9,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/action/bulk/TransportShardBulkAction.java': {'filename': 'TransportShardBulkAction.java',
#   'total_loc': 599,
#   'Martijn van Groningen': 406,
#   'Boaz Leskes': 119,
#   'Shay Banon': 38,
#   'Simon Willnauer': 34,
#   'Lee Hinman': 2},
#  'src/main/java/org/elasticsearch/action/update/TransportUpdateAction.java': {'filename': 'TransportUpdateAction.java',
#   'total_loc': 411,
#   'Martijn van Groningen': 369,
#   'Boaz Leskes': 8,
#   'Shay Banon': 8,
#   'Simon Willnauer': 26},
#  'src/main/java/org/elasticsearch/action/update/UpdateHelper.java': {'filename': 'UpdateHelper.java',
#   'total_loc': 327,
#   'Martijn van Groningen': 265,
#   'Boaz Leskes': 35,
#   'Marcus Granström': 4,
#   'Simon Willnauer': 4,
#   'Igor Motov': 19},
#  'src/main/java/org/elasticsearch/action/update/UpdateRequest.java': {'filename': 'UpdateRequest.java',
#   'total_loc': 158,
#   'Martijn van Groningen': 28,
#   'Alexander Kahn': 3,
#   'Marcus Granström': 25,
#   'Boaz Leskes': 63,
#   'Benjamin Devèze': 3,
#   'Shay Banon': 22,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/action/update/UpdateResponse.java': {'filename': 'UpdateResponse.java',
#   'total_loc': 88,
#   'Martijn van Groningen': 50,
#   'Boaz Leskes': 16,
#   'Shay Banon': 8,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/indices/IndicesModule.java': {'filename': 'IndicesModule.java',
#   'total_loc': 20,
#   'Martijn van Groningen': 2,
#   'Lee Hinman': 4,
#   'Simon Willnauer': 14},
#  'src/test/java/org/elasticsearch/test/integration/document/BulkTests.java': {'filename': 'BulkTests.java',
#   'total_loc': 722,
#   'Martijn van Groningen': 310,
#   'Simon Willnauer': 141,
#   'Boaz Leskes': 113,
#   'Shay Banon': 4,
#   'Luca Cavanna': 154},
#  'src/test/java/org/elasticsearch/test/integration/update/UpdateTests.java': {'filename': 'UpdateTests.java',
#   'total_loc': 536,
#   'Martijn van Groningen': 149,
#   'Simon Willnauer': 202,
#   'Boaz Leskes': 90,
#   'Marcus Granström': 63,
#   'Benjamin Devèze': 14,
#   'Shay Banon': 18},
#  'src/test/java/org/elasticsearch/test/unit/action/bulk/BulkRequestTests.java': {'filename': 'BulkRequestTests.java',
#   'total_loc': 42,
#   'Martijn van Groningen': 21,
#   'Simon Willnauer': 21},
#  'src/main/java/org/elasticsearch/index/fielddata/BytesValues.java': {'filename': 'BytesValues.java',
#   'total_loc': 498,
#   'Shay Banon': 47,
#   'Adrien Grand': 42,
#   'Simon Willnauer': 409},
#  'src/main/java/org/elasticsearch/index/fielddata/plain/FSTBytesAtomicFieldData.java': {'filename': 'FSTBytesAtomicFieldData.java',
#   'total_loc': 309,
#   'Shay Banon': 39,
#   'Adrien Grand': 52,
#   'Martijn van Groningen': 9,
#   'Simon Willnauer': 198,
#   'uboness': 11},
#  'src/main/java/org/elasticsearch/index/fielddata/plain/PagedBytesAtomicFieldData.java': {'filename': 'PagedBytesAtomicFieldData.java',
#   'total_loc': 285,
#   'Shay Banon': 29,
#   'Adrien Grand': 62,
#   'Martijn van Groningen': 10,
#   'Simon Willnauer': 169,
#   'uboness': 15},
#  'src/main/java/org/elasticsearch/search/facet/terms/strings/HashedAggregator.java': {'filename': 'HashedAggregator.java',
#   'total_loc': 88,
#   'Shay Banon': 26,
#   'uboness': 12,
#   'Martijn van Groningen': 8,
#   'Simon Willnauer': 42},
#  'src/main/java/org/elasticsearch/search/facet/termsstats/strings/TermsStatsStringFacetExecutor.java': {'filename': 'TermsStatsStringFacetExecutor.java',
#   'total_loc': 98,
#   'Shay Banon': 47,
#   'uboness': 8,
#   'Martijn van Groningen': 23,
#   'Simon Willnauer': 20},
#  'src/main/java/org/elasticsearch/index/fielddata/IndexFieldDataService.java': {'filename': 'IndexFieldDataService.java',
#   'total_loc': 216,
#   'Shay Banon': 1,
#   'Adrien Grand': 183,
#   'Lee Hinman': 12,
#   'Simon Willnauer': 20},
#  'src/main/java/org/elasticsearch/index/fielddata/plain/ConcreteBytesRefAtomicFieldData.java': {'filename': 'ConcreteBytesRefAtomicFieldData.java',
#   'total_loc': 296,
#   'Shay Banon': 296},
#  'src/main/java/org/elasticsearch/index/fielddata/plain/ConcreteBytesRefIndexFieldData.java': {'filename': 'ConcreteBytesRefIndexFieldData.java',
#   'total_loc': 81,
#   'Shay Banon': 81},
#  'src/test/java/org/elasticsearch/test/integration/search/facet/ExtendedFacetsTests.java': {'filename': 'ExtendedFacetsTests.java',
#   'total_loc': 288,
#   'Shay Banon': 17,
#   'Simon Willnauer': 271},
#  'src/test/java/org/elasticsearch/test/unit/index/fielddata/ConcreteBytesStringFieldDataTests.java': {'filename': 'ConcreteBytesStringFieldDataTests.java',
#   'total_loc': 35,
#   'Shay Banon': 35},
#  'src/main/java/org/elasticsearch/http/netty/NettyHttpChannel.java': {'filename': 'NettyHttpChannel.java',
#   'total_loc': 70,
#   'Alexander Reelsen': 12,
#   'Shay Banon': 44,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/rest/AbstractRestResponse.java': {'filename': 'AbstractRestResponse.java',
#   'total_loc': 39,
#   'Alexander Reelsen': 25,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/rest/RestResponse.java': {'filename': 'RestResponse.java',
#   'total_loc': 23,
#   'Alexander Reelsen': 9,
#   'Simon Willnauer': 14},
#  'src/test/java/org/elasticsearch/test/integration/nodesinfo/SimpleNodesInfoTests.java': {'filename': 'SimpleNodesInfoTests.java',
#   'total_loc': 175,
#   'Alexander Reelsen': 169,
#   'Simon Willnauer': 6},
#  'src/test/java/org/elasticsearch/test/integration/plugin/ResponseHeaderPluginTests.java': {'filename': 'ResponseHeaderPluginTests.java',
#   'total_loc': 116,
#   'Alexander Reelsen': 94,
#   'Simon Willnauer': 22},
#  'src/test/java/org/elasticsearch/test/integration/plugin/responseheader/TestResponseHeaderPlugin.java': {'filename': 'TestResponseHeaderPlugin.java',
#   'total_loc': 40,
#   'Alexander Reelsen': 40},
#  'src/test/java/org/elasticsearch/test/integration/plugin/responseheader/TestResponseHeaderRestAction.java': {'filename': 'TestResponseHeaderRestAction.java',
#   'total_loc': 46,
#   'Alexander Reelsen': 46},
#  'src/test/java/org/elasticsearch/test/integration/rest/helper/HttpClient.java': {'filename': 'HttpClient.java',
#   'total_loc': 47,
#   'Alexander Reelsen': 18,
#   'Simon Willnauer': 10,
#   'Shay Banon': 9,
#   'Luca Cavanna': 10},
#  'src/test/java/org/elasticsearch/test/integration/rest/helper/HttpClientResponse.java': {'filename': 'HttpClientResponse.java',
#   'total_loc': 22,
#   'Alexander Reelsen': 22},
#  'src/main/java/org/elasticsearch/action/search/ShardSearchFailure.java': {'filename': 'ShardSearchFailure.java',
#   'total_loc': 41,
#   'Shay Banon': 21,
#   'Simon Willnauer': 20},
#  'src/main/java/org/elasticsearch/action/search/type/TransportSearchTypeAction.java': {'filename': 'TransportSearchTypeAction.java',
#   'total_loc': 455,
#   'Shay Banon': 366,
#   'Simon Willnauer': 52,
#   'Boaz Leskes': 31,
#   'Martijn van Groningen': 6},
#  'src/test/java/org/elasticsearch/test/unit/deps/lucene/LuceneFieldCacheTests.java': {'filename': 'LuceneFieldCacheTests.java',
#   'total_loc': 63,
#   'Shay Banon': 63},
#  'src/main/java/org/elasticsearch/indices/cluster/IndicesClusterStateService.java': {'filename': 'IndicesClusterStateService.java',
#   'total_loc': 545,
#   'Shay Banon': 234,
#   'Clinton Gormley': 4,
#   'Luca Cavanna': 64,
#   'Simon Willnauer': 81,
#   'Boaz Leskes': 98,
#   'Igor Motov': 50,
#   'Martijn van Groningen': 14},
#  'src/main/java/org/elasticsearch/transport/local/LocalTransport.java': {'filename': 'LocalTransport.java',
#   'total_loc': 170,
#   'Shay Banon': 140,
#   'Simon Willnauer': 30},
#  'src/main/java/org/elasticsearch/transport/netty/MessageChannelHandler.java': {'filename': 'MessageChannelHandler.java',
#   'total_loc': 51,
#   'Shay Banon': 33,
#   'Simon Willnauer': 18},
#  'src/main/java/org/joda/time/base/BaseDateTime.java': {'filename': 'BaseDateTime.java',
#   'total_loc': 8,
#   'Shay Banon': 7,
#   'Igor Motov': 1},
#  'src/main/java/org/elasticsearch/common/settings/ImmutableSettings.java': {'filename': 'ImmutableSettings.java',
#   'total_loc': 208,
#   'Shay Banon': 41,
#   'Simon Willnauer': 27,
#   'Clinton Gormley': 19,
#   'Adrien Grand': 15,
#   'Igor Motov': 106},
#  'src/test/java/org/elasticsearch/test/unit/common/settings/ImmutableSettingsTests.java': {'filename': 'ImmutableSettingsTests.java',
#   'total_loc': 65,
#   'Shay Banon': 37,
#   'Simon Willnauer': 28},
#  'src/main/java/org/elasticsearch/index/query/HasChildQueryParser.java': {'filename': 'HasChildQueryParser.java',
#   'total_loc': 94,
#   'Martijn van Groningen': 76,
#   'Boaz Leskes': 4,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/index/query/HasParentQueryParser.java': {'filename': 'HasParentQueryParser.java',
#   'total_loc': 130,
#   'Martijn van Groningen': 113,
#   'Simon Willnauer': 17},
#  'src/main/java/org/elasticsearch/index/query/TopChildrenQueryParser.java': {'filename': 'TopChildrenQueryParser.java',
#   'total_loc': 59,
#   'Martijn van Groningen': 40,
#   'Shay Banon': 2,
#   'Simon Willnauer': 17},
#  'src/main/java/org/elasticsearch/index/search/child/ScoreType.java': {'filename': 'ScoreType.java',
#   'total_loc': 23,
#   'Martijn van Groningen': 2,
#   'Simon Willnauer': 21},
#  'src/main/java/org/elasticsearch/index/query/NestedQueryParser.java': {'filename': 'NestedQueryParser.java',
#   'total_loc': 22,
#   'Martijn van Groningen': 8,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/index/cache/id/IdCache.java': {'filename': 'IdCache.java',
#   'total_loc': 28,
#   'Martijn van Groningen': 8,
#   'Simon Willnauer': 20},
#  'src/main/java/org/elasticsearch/index/cache/id/simple/SimpleIdCache.java': {'filename': 'SimpleIdCache.java',
#   'total_loc': 221,
#   'Martijn van Groningen': 175,
#   'Simon Willnauer': 38,
#   'Adrien Grand': 6,
#   'Dan Everton': 2},
#  'src/test/java/org/elasticsearch/benchmark/search/child/ChildSearchBenchmark.java': {'filename': 'ChildSearchBenchmark.java',
#   'total_loc': 122,
#   'Martijn van Groningen': 103,
#   'Simon Willnauer': 19},
#  'src/main/java/org/elasticsearch/index/analysis/AnalysisModule.java': {'filename': 'AnalysisModule.java',
#   'total_loc': 43,
#   'Brusic': 1,
#   'Cédric HOURCADE': 1,
#   'Alexander Reelsen': 7,
#   'Clinton Gormley': 1,
#   'Britta Weber': 1,
#   'Simon Willnauer': 32},
#  'src/main/java/org/elasticsearch/index/analysis/LimitTokenCountFilterFactory.java': {'filename': 'LimitTokenCountFilterFactory.java',
#   'total_loc': 64,
#   'Brusic': 50,
#   'Simon Willnauer': 14},
#  'src/test/java/org/elasticsearch/test/unit/index/analysis/LimitTokenCountFilterFactoryTests.java': {'filename': 'LimitTokenCountFilterFactoryTests.java',
#   'total_loc': 136,
#   'Simon Willnauer': 136},
#  'src/main/java/org/elasticsearch/cluster/routing/allocation/decider/DisableAllocationDecider.java': {'filename': 'DisableAllocationDecider.java',
#   'total_loc': 35,
#   'Shay Banon': 18,
#   'Simon Willnauer': 14,
#   'Martijn van Groningen': 3},
#  'src/main/java/org/elasticsearch/index/settings/IndexDynamicSettingsModule.java': {'filename': 'IndexDynamicSettingsModule.java',
#   'total_loc': 42,
#   'Shay Banon': 9,
#   'Alexander Reelsen': 2,
#   'Simon Willnauer': 29,
#   'Martijn van Groningen': 2},
#  'src/test/java/org/elasticsearch/test/unit/cluster/routing/allocation/AllocationCommandsTests.java': {'filename': 'AllocationCommandsTests.java',
#   'total_loc': 12,
#   'Shay Banon': 9,
#   'Simon Willnauer': 3},
#  'src/test/java/org/elasticsearch/test/unit/cluster/routing/allocation/DisableAllocationTests.java': {'filename': 'DisableAllocationTests.java',
#   'total_loc': 56,
#   'Shay Banon': 53,
#   'Simon Willnauer': 3},
#  'src/test/java/org/elasticsearch/test/unit/cluster/settings/ClusterSettingsTests.java': {'filename': 'ClusterSettingsTests.java',
#   'total_loc': 40,
#   'Shay Banon': 19,
#   'Simon Willnauer': 2,
#   'Boaz Leskes': 19},
#  'src/main/java/org/elasticsearch/index/query/HasChildFilterParser.java': {'filename': 'HasChildFilterParser.java',
#   'total_loc': 77,
#   'Martijn van Groningen': 56,
#   'Boaz Leskes': 4,
#   'Simon Willnauer': 17},
#  'src/main/java/org/elasticsearch/index/query/HasParentFilterParser.java': {'filename': 'HasParentFilterParser.java',
#   'total_loc': 101,
#   'Martijn van Groningen': 84,
#   'Simon Willnauer': 17},
#  'src/main/java/org/elasticsearch/index/search/child/HasChildFilter.java': {'filename': 'HasChildFilter.java',
#   'total_loc': 414,
#   'Martijn van Groningen': 382,
#   'Shay Banon': 30,
#   'Adrien Grand': 2},
#  'src/main/java/org/elasticsearch/index/search/child/HasParentFilter.java': {'filename': 'HasParentFilter.java',
#   'total_loc': 382,
#   'Martijn van Groningen': 357,
#   'Shay Banon': 25},
#  'src/main/java/org/elasticsearch/search/facet/FacetParseElement.java': {'filename': 'FacetParseElement.java',
#   'total_loc': 30,
#   'uboness': 3,
#   'Luca Cavanna': 6,
#   'Simon Willnauer': 21},
#  'src/main/java/org/elasticsearch/search/facet/FacetParsers.java': {'filename': 'FacetParsers.java',
#   'total_loc': 33,
#   'uboness': 16,
#   'Simon Willnauer': 17},
#  'src/main/java/org/elasticsearch/search/facet/histogram/HistogramFacetParser.java': {'filename': 'HistogramFacetParser.java',
#   'total_loc': 19,
#   'uboness': 2,
#   'Simon Willnauer': 17},
#  'src/main/java/org/elasticsearch/search/facet/range/RangeFacetParser.java': {'filename': 'RangeFacetParser.java',
#   'total_loc': 19,
#   'uboness': 2,
#   'Simon Willnauer': 17},
#  'src/main/java/org/elasticsearch/search/facet/terms/TermsFacetParser.java': {'filename': 'TermsFacetParser.java',
#   'total_loc': 96,
#   'uboness': 50,
#   'Shay Banon': 6,
#   'Boaz Leskes': 13,
#   'Simon Willnauer': 27},
#  'src/main/java/org/elasticsearch/search/facet/terms/doubles/InternalDoubleTermsFacet.java': {'filename': 'InternalDoubleTermsFacet.java',
#   'total_loc': 102,
#   'uboness': 45,
#   'Simon Willnauer': 20,
#   'Shay Banon': 19,
#   'Martijn van Groningen': 18},
#  'src/main/java/org/elasticsearch/search/facet/terms/longs/InternalLongTermsFacet.java': {'filename': 'InternalLongTermsFacet.java',
#   'total_loc': 100,
#   'uboness': 45,
#   'Simon Willnauer': 20,
#   'Shay Banon': 17,
#   'Martijn van Groningen': 18},
#  'src/main/java/org/elasticsearch/search/facet/terms/strings/FieldsTermsStringFacetExecutor.java': {'filename': 'FieldsTermsStringFacetExecutor.java',
#   'total_loc': 38,
#   'uboness': 22,
#   'Simon Willnauer': 16},
#  'src/main/java/org/elasticsearch/search/facet/terms/strings/InternalStringTermsFacet.java': {'filename': 'InternalStringTermsFacet.java',
#   'total_loc': 103,
#   'uboness': 47,
#   'Simon Willnauer': 17,
#   'Shay Banon': 19,
#   'Martijn van Groningen': 20},
#  'src/main/java/org/elasticsearch/search/facet/terms/unmapped/UnmappedFieldExecutor.java': {'filename': 'UnmappedFieldExecutor.java',
#   'total_loc': 94,
#   'uboness': 77,
#   'Simon Willnauer': 17},
#  'src/main/java/org/elasticsearch/search/facet/termsstats/TermsStatsFacetParser.java': {'filename': 'TermsStatsFacetParser.java',
#   'total_loc': 37,
#   'uboness': 19,
#   'Martijn van Groningen': 4,
#   'Simon Willnauer': 14},
#  'src/test/java/org/elasticsearch/test/integration/search/facet/terms/UnmappedFieldsTermsFacetsTests.java': {'filename': 'UnmappedFieldsTermsFacetsTests.java',
#   'total_loc': 597,
#   'uboness': 416,
#   'Simon Willnauer': 137,
#   'Shay Banon': 44},
#  'src/main/java/org/elasticsearch/threadpool/ThreadPool.java': {'filename': 'ThreadPool.java',
#   'total_loc': 487,
#   'Simon Willnauer': 43,
#   'Shay Banon': 432,
#   'Martijn van Groningen': 4,
#   'uboness': 8},
#  'src/main/java/org/elasticsearch/indices/store/IndicesStore.java': {'filename': 'IndicesStore.java',
#   'total_loc': 39,
#   'Simon Willnauer': 21,
#   'Shay Banon': 18},
#  'src/main/java/org/elasticsearch/cluster/settings/ClusterDynamicSettingsModule.java': {'filename': 'ClusterDynamicSettingsModule.java',
#   'total_loc': 28,
#   'Simon Willnauer': 15,
#   'Lee Hinman': 9,
#   'Igor Motov': 1,
#   'Martijn van Groningen': 3},
#  'src/main/java/org/elasticsearch/indices/recovery/RecoverySettings.java': {'filename': 'RecoverySettings.java',
#   'total_loc': 64,
#   'Simon Willnauer': 40,
#   'Shay Banon': 6,
#   'Lee Hinman': 18},
#  'src/main/java/org/elasticsearch/cluster/routing/operation/hash/djb/DjbHashFunction.java': {'filename': 'DjbHashFunction.java',
#   'total_loc': 25,
#   'Shay Banon': 11,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/common/lucene/uid/UidField.java': {'filename': 'UidField.java',
#   'total_loc': 214,
#   'Shay Banon': 1,
#   'Adrien Grand': 213},
#  'src/main/java/org/elasticsearch/common/MurmurHash.java': {'filename': 'MurmurHash.java',
#   'total_loc': 264,
#   'Shay Banon': 264},
#  'src/main/java/org/elasticsearch/common/Unicode.java': {'filename': 'Unicode.java',
#   'total_loc': 242,
#   'Shay Banon': 17,
#   'Simon Willnauer': 225},
#  'src/main/java/org/elasticsearch/common/util/concurrent/ThreadLocals.java': {'filename': 'ThreadLocals.java',
#   'total_loc': 193,
#   'Shay Banon': 33,
#   'Martijn van Groningen': 160},
#  'src/main/java/org/elasticsearch/node/internal/InternalNode.java': {'filename': 'InternalNode.java',
#   'total_loc': 97,
#   'Shay Banon': 53,
#   'Martijn van Groningen': 11,
#   'Andrew Raines': 2,
#   'Igor Motov': 7,
#   'Adrien Grand': 4,
#   'Simon Willnauer': 20},
#  'src/main/java/org/elasticsearch/rest/StringRestResponse.java': {'filename': 'StringRestResponse.java',
#   'total_loc': 32,
#   'Shay Banon': 18,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/rest/XContentRestResponse.java': {'filename': 'XContentRestResponse.java',
#   'total_loc': 40,
#   'Shay Banon': 13,
#   'Simon Willnauer': 27},
#  'src/main/java/org/elasticsearch/search/internal/InternalSearchHits.java': {'filename': 'InternalSearchHits.java',
#   'total_loc': 29,
#   'Shay Banon': 9,
#   'Martijn van Groningen': 6,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/discovery/zen/ZenDiscovery.java': {'filename': 'ZenDiscovery.java',
#   'total_loc': 279,
#   'Clinton Gormley': 2,
#   'Drew Raines': 4,
#   'Shay Banon': 193,
#   'Simon Willnauer': 54,
#   'Luca Cavanna': 4,
#   'Martijn van Groningen': 22},
#  'src/main/java/org/elasticsearch/action/mlt/MoreLikeThisRequest.java': {'filename': 'MoreLikeThisRequest.java',
#   'total_loc': 68,
#   'Martijn van Groningen': 11,
#   'Alexander Reelsen': 7,
#   'Simon Willnauer': 22,
#   'markharwood': 28},
#  'src/main/java/org/elasticsearch/action/mlt/TransportMoreLikeThisAction.java': {'filename': 'TransportMoreLikeThisAction.java',
#   'total_loc': 71,
#   'Martijn van Groningen': 5,
#   'Adrien Grand': 16,
#   'Simon Willnauer': 36,
#   'Leonardo Menezes': 3,
#   'Igor Motov': 7,
#   'markharwood': 4},
#  'src/test/java/org/elasticsearch/test/integration/mlt/MoreLikeThisActionTests.java': {'filename': 'MoreLikeThisActionTests.java',
#   'total_loc': 386,
#   'Martijn van Groningen': 58,
#   'Simon Willnauer': 207,
#   'Adrien Grand': 84,
#   'Boaz Leskes': 37},
#  'src/main/java/org/elasticsearch/search/suggest/phrase/DirectCandidateGenerator.java': {'filename': 'DirectCandidateGenerator.java',
#   'total_loc': 70,
#   'Simon Willnauer': 51,
#   'Nik Everett': 17,
#   'Adrien Grand': 2},
#  'src/test/java/org/elasticsearch/test/integration/search/suggest/SuggestSearchTests.java': {'filename': 'SuggestSearchTests.java',
#   'total_loc': 2489,
#   'Simon Willnauer': 774,
#   'Nik Everett': 1665,
#   'David Pilato': 50},
#  'src/test/java/org/elasticsearch/test/unit/index/cache/id/SimpleIdCacheTests.java': {'filename': 'SimpleIdCacheTests.java',
# ...
#   'total_loc': 288,
#   'Adrien Grand': 144,
#   'Simon Willnauer': 144},
#  'src/main/java/org/apache/lucene/search/vectorhighlight/XBaseFragmentsBuilder.java': {'filename': 'XBaseFragmentsBuilder.java',
#   'total_loc': 664,
#   'Adrien Grand': 332,
#   'Simon Willnauer': 332},
#  'src/main/java/org/apache/lucene/search/vectorhighlight/XFastVectorHighlighter.java': {'filename': 'XFastVectorHighlighter.java',
#   'total_loc': 446,
#   'Adrien Grand': 223,
#   'Simon Willnauer': 223},
#  'src/main/java/org/apache/lucene/search/vectorhighlight/XFieldFragList.java': {'filename': 'XFieldFragList.java',
#   'total_loc': 284,
#   'Adrien Grand': 142,
#   'Simon Willnauer': 142},
#  'src/main/java/org/apache/lucene/search/vectorhighlight/XFieldPhraseList.java': {'filename': 'XFieldPhraseList.java',
#   'total_loc': 528,
#   'Adrien Grand': 261,
#   'Simon Willnauer': 267},
#  'src/main/java/org/apache/lucene/search/vectorhighlight/XFieldQuery.java': {'filename': 'XFieldQuery.java',
#   'total_loc': 1092,
#   'Adrien Grand': 520,
#   'Simon Willnauer': 572},
#  'src/main/java/org/apache/lucene/search/vectorhighlight/XFieldTermStack.java': {'filename': 'XFieldTermStack.java',
#   'total_loc': 426,
#   'Adrien Grand': 209,
#   'Simon Willnauer': 217},
#  'src/main/java/org/apache/lucene/search/vectorhighlight/XFragListBuilder.java': {'filename': 'XFragListBuilder.java',
#   'total_loc': 70,
#   'Adrien Grand': 35,
#   'Simon Willnauer': 35},
#  'src/main/java/org/apache/lucene/search/vectorhighlight/XFragmentsBuilder.java': {'filename': 'XFragmentsBuilder.java',
#   'total_loc': 192,
#   'Adrien Grand': 96,
#   'Simon Willnauer': 96},
#  'src/main/java/org/apache/lucene/search/vectorhighlight/XScoreOrderFragmentsBuilder.java': {'filename': 'XScoreOrderFragmentsBuilder.java',
#   'total_loc': 168,
#   'Adrien Grand': 84,
#   'Simon Willnauer': 84},
#  'src/main/java/org/apache/lucene/search/vectorhighlight/XSimpleFieldFragList.java': {'filename': 'XSimpleFieldFragList.java',
#   'total_loc': 110,
#   'Adrien Grand': 55,
#   'Simon Willnauer': 55},
#  'src/main/java/org/apache/lucene/search/vectorhighlight/XSimpleFragmentsBuilder.java': {'filename': 'XSimpleFragmentsBuilder.java',
#   'total_loc': 126,
#   'Adrien Grand': 63,
#   'Simon Willnauer': 63},
#  'src/main/java/org/apache/lucene/search/vectorhighlight/XSingleFragListBuilder.java': {'filename': 'XSingleFragListBuilder.java',
#   'total_loc': 120,
#   'Adrien Grand': 60,
#   'Simon Willnauer': 60},
#  'src/main/java/org/elasticsearch/common/lucene/search/vectorhighlight/SimpleBoundaryScanner2.java': {'filename': 'SimpleBoundaryScanner2.java',
#   'total_loc': 64,
#   'Adrien Grand': 2,
#   'Shay Banon': 62},
#  'src/test/java/org/elasticsearch/test/unit/deps/lucene/VectorHighlighterTests.java': {'filename': 'VectorHighlighterTests.java',
#   'total_loc': 41,
#   'Adrien Grand': 10,
#   'Simon Willnauer': 18,
#   'Shay Banon': 13},
#  'src/main/java/org/elasticsearch/action/admin/cluster/health/TransportClusterHealthAction.java': {'filename': 'TransportClusterHealthAction.java',
#   'total_loc': 154,
#   'Shay Banon': 24,
#   'Boaz Leskes': 112,
#   'Simon Willnauer': 18},
#  'src/main/java/org/elasticsearch/action/admin/cluster/node/shutdown/TransportNodesShutdownAction.java': {'filename': 'TransportNodesShutdownAction.java',
#   'total_loc': 42,
#   'Shay Banon': 7,
#   'Martijn van Groningen': 11,
#   'Simon Willnauer': 24},
#  'src/main/java/org/elasticsearch/action/admin/cluster/shards/TransportClusterSearchShardsAction.java': {'filename': 'TransportClusterSearchShardsAction.java',
#   'total_loc': 28,
#   'Shay Banon': 8,
#   'Martijn van Groningen': 2,
#   'Simon Willnauer': 18},
#  'src/main/java/org/elasticsearch/action/admin/cluster/state/TransportClusterStateAction.java': {'filename': 'TransportClusterStateAction.java',
#   'total_loc': 86,
#   'Shay Banon': 19,
#   'Boaz Leskes': 4,
#   'Luca Cavanna': 4,
#   'Simon Willnauer': 18,
#   'Alexander Reelsen': 41},
#  'src/main/java/org/elasticsearch/action/admin/indices/exists/indices/TransportIndicesExistsAction.java': {'filename': 'TransportIndicesExistsAction.java',
#   'total_loc': 38,
#   'Shay Banon': 7,
#   'Martijn van Groningen': 13,
#   'Simon Willnauer': 18},
#  'src/main/java/org/elasticsearch/action/admin/indices/exists/types/TransportTypesExistsAction.java': {'filename': 'TransportTypesExistsAction.java',
#   'total_loc': 53,
#   'Shay Banon': 20,
#   'Martijn van Groningen': 12,
#   'Simon Willnauer': 21},
#  'src/main/java/org/elasticsearch/action/support/master/TransportMasterNodeOperationAction.java': {'filename': 'TransportMasterNodeOperationAction.java',
#   'total_loc': 59,
#   'Shay Banon': 35,
#   'Boaz Leskes': 2,
#   'Simon Willnauer': 22},
#  'src/main/java/org/elasticsearch/cluster/ClusterStateUpdateTask.java': {'filename': 'ClusterStateUpdateTask.java',
#   'total_loc': 23,
#   'Shay Banon': 9,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/cluster/ProcessedClusterStateUpdateTask.java': {'filename': 'ProcessedClusterStateUpdateTask.java',
#   'total_loc': 18,
#   'Shay Banon': 4,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/cluster/action/index/MappingUpdatedAction.java': {'filename': 'MappingUpdatedAction.java',
#   'total_loc': 131,
#   'Shay Banon': 80,
#   'Boaz Leskes': 27,
#   'Luca Cavanna': 6,
#   'Simon Willnauer': 18},
#  'src/main/java/org/elasticsearch/cluster/routing/RoutingService.java': {'filename': 'RoutingService.java',
#   'total_loc': 30,
#   'Shay Banon': 8,
#   'Simon Willnauer': 22},
#  'src/main/java/org/elasticsearch/discovery/local/LocalDiscovery.java': {'filename': 'LocalDiscovery.java',
#   'total_loc': 179,
#   'Shay Banon': 109,
#   'Luca Cavanna': 42,
#   'Simon Willnauer': 28},
#  'src/main/java/org/elasticsearch/gateway/GatewayService.java': {'filename': 'GatewayService.java',
#   'total_loc': 52,
#   'Shay Banon': 25,
#   'Martijn van Groningen': 5,
#   'Simon Willnauer': 22},
#  'src/main/java/org/elasticsearch/gateway/local/state/meta/LocalAllocateDangledIndices.java': {'filename': 'LocalAllocateDangledIndices.java',
#   'total_loc': 43,
#   'Shay Banon': 27,
#   'Simon Willnauer': 16},
#  'src/main/java/org/elasticsearch/action/admin/indices/optimize/TransportOptimizeAction.java': {'filename': 'TransportOptimizeAction.java',
#   'total_loc': 48,
#   'Shay Banon': 30,
#   'Simon Willnauer': 18},
#  'src/main/java/org/elasticsearch/common/lucene/all/AllTermQuery.java': {'filename': 'AllTermQuery.java',
#   'total_loc': 68,
#   'Simon Willnauer': 23,
#   'Adrien Grand': 45},
#  'src/main/java/org/elasticsearch/index/analysis/KeepWordFilterFactory.java': {'filename': 'KeepWordFilterFactory.java',
#   'total_loc': 86,
#   'Simon Willnauer': 38,
#   'Vojtech Hyza': 45,
#   'Igor Motov': 3},
#  'src/main/java/org/elasticsearch/index/analysis/LengthTokenFilterFactory.java': {'filename': 'LengthTokenFilterFactory.java',
#   'total_loc': 35,
#   'Simon Willnauer': 35},
#  'src/main/java/org/elasticsearch/index/analysis/TrimTokenFilterFactory.java': {'filename': 'TrimTokenFilterFactory.java',
#   'total_loc': 31,
#   'Simon Willnauer': 31},
#  'src/main/java/org/elasticsearch/index/merge/scheduler/ConcurrentMergeSchedulerProvider.java': {'filename': 'ConcurrentMergeSchedulerProvider.java',
#   'total_loc': 39,
#   'Simon Willnauer': 17,
#   'Shay Banon': 22},
#  'src/main/java/org/elasticsearch/action/admin/cluster/tasks/PendingClusterTasksAction.java': {'filename': 'PendingClusterTasksAction.java',
#   'total_loc': 59,
#   'Martijn van Groningen': 45,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/action/admin/cluster/tasks/PendingClusterTasksRequest.java': {'filename': 'PendingClusterTasksRequest.java',
#   'total_loc': 47,
#   'Martijn van Groningen': 33,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/action/admin/cluster/tasks/PendingClusterTasksRequestBuilder.java': {'filename': 'PendingClusterTasksRequestBuilder.java',
#   'total_loc': 53,
#   'Martijn van Groningen': 39,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/action/admin/cluster/tasks/PendingClusterTasksResponse.java': {'filename': 'PendingClusterTasksResponse.java',
#   'total_loc': 153,
#   'Martijn van Groningen': 82,
#   'Shay Banon': 55,
#   'Andrew Raines': 2,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/action/admin/cluster/tasks/TransportPendingClusterTasksAction.java': {'filename': 'TransportPendingClusterTasksAction.java',
#   'total_loc': 87,
#   'Martijn van Groningen': 69,
#   'Simon Willnauer': 18},
#  'src/main/java/org/elasticsearch/client/ClusterAdminClient.java': {'filename': 'ClusterAdminClient.java',
#   'total_loc': 186,
#   'Martijn van Groningen': 21,
#   'Igor Motov': 126,
#   'Boaz Leskes': 25,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/client/support/AbstractClusterAdminClient.java': {'filename': 'AbstractClusterAdminClient.java',
#   'total_loc': 184,
#   'Martijn van Groningen': 17,
#   'Igor Motov': 134,
#   'Boaz Leskes': 19,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/cluster/ClusterService.java': {'filename': 'ClusterService.java',
#   'total_loc': 31,
#   'Martijn van Groningen': 8,
#   'Simon Willnauer': 18,
#   'Shay Banon': 5},
#  'src/main/java/org/elasticsearch/cluster/service/PendingClusterTask.java': {'filename': 'PendingClusterTask.java',
#   'total_loc': 115,
#   'Martijn van Groningen': 101,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/rest/action/admin/cluster/tasks/RestPendingClusterTasksAction.java': {'filename': 'RestPendingClusterTasksAction.java',
#   'total_loc': 137,
#   'Martijn van Groningen': 97,
#   'Shay Banon': 25,
#   'Alexander Reelsen': 1,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/cluster/ClusterState.java': {'filename': 'ClusterState.java',
#   'total_loc': 170,
#   'Shay Banon': 59,
#   'Igor Motov': 23,
#   'Martijn van Groningen': 68,
#   'Simon Willnauer': 20},
#  'src/main/java/org/elasticsearch/common/compress/CompressorFactory.java': {'filename': 'CompressorFactory.java',
#   'total_loc': 28,
#   'Shay Banon': 14,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/common/io/CachedStreams.java': {'filename': 'CachedStreams.java',
#   'total_loc': 16,
#   'Shay Banon': 2,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/common/io/FastByteArrayInputStream.java': {'filename': 'FastByteArrayInputStream.java',
#   'total_loc': 268,
#   'Shay Banon': 268},
#  'src/main/java/org/elasticsearch/common/io/stream/BytesStreamOutput.java': {'filename': 'BytesStreamOutput.java',
#   'total_loc': 40,
#   'Shay Banon': 26,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/common/io/stream/CachedStreamOutput.java': {'filename': 'CachedStreamOutput.java',
#   'total_loc': 172,
#   'Shay Banon': 172},
#  'src/main/java/org/elasticsearch/common/settings/loader/PropertiesSettingsLoader.java': {'filename': 'PropertiesSettingsLoader.java',
#   'total_loc': 26,
#   'Shay Banon': 12,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/discovery/zen/ping/multicast/MulticastZenPing.java': {'filename': 'MulticastZenPing.java',
#   'total_loc': 73,
#   'Shay Banon': 20,
#   'Simon Willnauer': 53},
#  'src/main/java/org/elasticsearch/discovery/zen/publish/PublishClusterStateAction.java': {'filename': 'PublishClusterStateAction.java',
#   'total_loc': 275,
#   'Shay Banon': 232,
#   'Boaz Leskes': 1,
#   'Luca Cavanna': 28,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/gateway/blobstore/BlobStoreGateway.java': {'filename': 'BlobStoreGateway.java',
#   'total_loc': 34,
#   'Shay Banon': 16,
#   'Simon Willnauer': 18},
#  'src/main/java/org/elasticsearch/gateway/local/state/meta/LocalGatewayMetaState.java': {'filename': 'LocalGatewayMetaState.java',
#   'total_loc': 312,
#   'Shay Banon': 253,
#   'Simon Willnauer': 40,
#   'Igor Motov': 15,
#   'Martijn van Groningen': 4},
#  'src/main/java/org/elasticsearch/gateway/local/state/shards/LocalGatewayShardsState.java': {'filename': 'LocalGatewayShardsState.java',
#   'total_loc': 101,
#   'Shay Banon': 87,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/index/gateway/blobstore/BlobStoreIndexShardGateway.java': {'filename': 'BlobStoreIndexShardGateway.java',
#   'total_loc': 32,
#   'Shay Banon': 12,
#   'Simon Willnauer': 20},
#  'src/main/java/org/elasticsearch/index/mapper/core/BinaryFieldMapper.java': {'filename': 'BinaryFieldMapper.java',
#   'total_loc': 90,
#   'Shay Banon': 15,
#   'Adrien Grand': 34,
#   'Boaz Leskes': 13,
#   'Simon Willnauer': 20,
#   'Martijn van Groningen': 8},
#  'src/main/java/org/elasticsearch/transport/local/LocalTransportChannel.java': {'filename': 'LocalTransportChannel.java',
#   'total_loc': 110,
#   'Shay Banon': 96,
#   'Simon Willnauer': 14},
#  'src/main/java/org/elasticsearch/transport/netty/NettyTransportChannel.java': {'filename': 'NettyTransportChannel.java',
#   'total_loc': 63,
#   'Shay Banon': 49,
#   'Simon Willnauer': 14},
#  'src/test/java/org/elasticsearch/test/unit/common/io/streams/BytesStreamsTests.java': {'filename': 'BytesStreamsTests.java',
#   'total_loc': 19,
#   'Shay Banon': 16,
#   'Simon Willnauer': 3},
#  'src/test/java/org/elasticsearch/test/unit/common/xcontent/smile/JsonVsSmileTests.java': {'filename': 'JsonVsSmileTests.java',
#   'total_loc': 8,
#   'Shay Banon': 6,
#   'Simon Willnauer': 2},
#  'src/test/java/org/elasticsearch/test/unit/deps/jackson/JacksonLocationTests.java': {'filename': 'JacksonLocationTests.java',
#   'total_loc': 17,
#   'Shay Banon': 15,
#   'Simon Willnauer': 2},
#  'src/test/java/org/elasticsearch/test/unit/transport/AbstractSimpleTransportTests.java': {'filename': 'AbstractSimpleTransportTests.java',
#   'total_loc': 416,
#   'Shay Banon': 400,
#   'Simon Willnauer': 14,
#   'Britta Weber': 2},
#  'src/main/java/org/elasticsearch/cluster/action/index/NodeMappingRefreshAction.java': {'filename': 'NodeMappingRefreshAction.java',
#   'total_loc': 62,
#   'Shay Banon': 25,
#   'Boaz Leskes': 19,
#   'Simon Willnauer': 18},
#  'src/test/java/org/apache/lucene/analysis/miscellaneous/TruncateTokenFilterTests.java': {'filename': 'TruncateTokenFilterTests.java',
#   'total_loc': 34,
#   'Simon Willnauer': 31,
#   'Adrien Grand': 3},
#  'src/test/java/org/apache/lucene/analysis/miscellaneous/UniqueTokenFilterTests.java': {'filename': 'UniqueTokenFilterTests.java',
#   'total_loc': 38,
#   'Simon Willnauer': 33,
#   'Adrien Grand': 3,
#   'Andrew Raines': 2},
#  'src/test/java/org/apache/lucene/util/English.java': {'filename': 'English.java',
#   'total_loc': 188,
#   'Simon Willnauer': 188},
#  'src/test/java/org/elasticsearch/junit/listerners/ReproduceInfoPrinter.java': {'filename': 'ReproduceInfoPrinter.java',
#   'total_loc': 81,
#   'Simon Willnauer': 81},
#  'src/test/java/org/elasticsearch/test/TestNGLoggingListener.java': {'filename': 'TestNGLoggingListener.java',
#   'total_loc': 76,
#   'Simon Willnauer': 76},
#  'src/test/java/org/elasticsearch/test/integration/blocks/SimpleBlocksTests.java': {'filename': 'SimpleBlocksTests.java',
#   'total_loc': 11,
#   'Simon Willnauer': 11},
#  'src/test/java/org/elasticsearch/test/integration/client/transport/DiscoveryTransportClientTests.java': {'filename': 'DiscoveryTransportClientTests.java',
#   'total_loc': 67,
#   'Simon Willnauer': 7,
#   'Shay Banon': 60},
#  'src/test/java/org/elasticsearch/test/integration/cluster/AbstractZenNodesTests.java': {'filename': 'AbstractZenNodesTests.java',
#   'total_loc': 13,
#   'Simon Willnauer': 10,
#   'Shay Banon': 3},
#  'src/test/java/org/elasticsearch/test/integration/cluster/MinimumMasterNodesTests.java': {'filename': 'MinimumMasterNodesTests.java',
#   'total_loc': 82,
#   'Simon Willnauer': 82},
#  'src/test/java/org/elasticsearch/test/integration/cluster/NoMasterNodeTests.java': {'filename': 'NoMasterNodeTests.java',
#   'total_loc': 29,
#   'Simon Willnauer': 17,
#   'Martijn van Groningen': 12},
#  'src/test/java/org/elasticsearch/test/integration/cluster/SpecificMasterNodesTests.java': {'filename': 'SpecificMasterNodesTests.java',
#   'total_loc': 6,
#   'Simon Willnauer': 6},
#  'src/test/java/org/elasticsearch/test/integration/cluster/UpdateSettingsValidationTests.java': {'filename': 'UpdateSettingsValidationTests.java',
#   'total_loc': 6,
#   'Simon Willnauer': 6},
#  'src/test/java/org/elasticsearch/test/integration/cluster/allocation/AwarenessAllocationTests.java': {'filename': 'AwarenessAllocationTests.java',
#   'total_loc': 120,
#   'Simon Willnauer': 120},
#  ...}

# %%
main_contributer = "Martijn van Groningen"
loss_main_conributer = {}

for filepath in contributions:
    contributions_main_contributer = 0
    print(contributions[filepath])
    if main_contributer in contributions[filepath]:
        print(contributions_main_contributer)
    loss_main_conributer[filepath] =  {
        "author_color": "blue",
        "size": contributions[filepath]["total_loc"],
        "name": contributions[filepath]["filename"],
        "weight": contributions[filepath]["total_loc"],
        "ownership": contributions_main_contributer / contributions[filepath]["total_loc"],
        "children": []
    }
print(loss_main_conributer)
print(len(loss_main_conributer))
# Out:
# {'filename': 'Version.java', 'total_loc': 170, 'Shay Banon': 73, 'Simon Willnauer': 69, 'Alexander Reelsen': 10, 'Adrien Grand': 2, 'Boaz Leskes': 14, 'Kevin Kluge': 2}
# {'filename': 'SimpleQueryTests.java', 'total_loc': 1739, 'Simon Willnauer': 1319, 'Martijn van Groningen': 21, 'Shay Banon': 302, 'Clinton Gormley': 12, 'Cédric HOURCADE': 24, 'Nik Everett': 32, 'uboness': 29}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 8
#       6 print(contributions[filepath])
#       7 if main_contributer in contributions[filepath]:
# ----> 8     contributions_main_contributer = filepath[main_contributer]
#       9     print(contributions_main_contributer)
#      10 loss_main_conributer[filepath] =  {
#      11     "author_color": "blue",
#      12     "size": contributions[filepath]["total_loc"],
#    (...)     16     "children": []
#      17 }
#
# TypeError: string indices must be integers, not 'str'

# %%
# Out:
# ['src', 'main', 'java', 'org', 'elasticsearch', 'Version.java']
# ['src', 'test', 'java', 'org', 'elasticsearch', 'test', 'integration', 'search', 'query', 'SimpleQueryTests.java']

# %%
'''
tree_structure = {}

tree = {
  "name": "root",
  "children": []}

i = 0
for filepath in loss_main_conributer:
    if i >= 2:
        break
    i+=1

    path_split = filepath.split("/") 
    parent=tree_structure
    for item in path_split:
        if not item.endswith(".java"):
                        
            
            
            if item not in parent:
                parent[item] = {}
            parent = parent[item]
        else:
            parent[item] = loss_main_conributer[filepath]        

tree_structure
'''
print("not used")
# Out:
# not used

# %%
tree = {
  "name": "root",
  "children": []}

for filepath in loss_main_conributer:
    path_split = filepath.split("/") 
    parent = tree
    for item in path_split:
        children = parent["children"]
        index = None
        if item.endswith(".java"):
            children.append(loss_main_conributer[filepath])
        else:
            for i, child in enumerate(children):
                if child["name"] == item:
                    index = i
            if index is None:
                children.append({"name": item, "children": []})
                index = len(children) - 1
            parent = parent["children"][index]

with open("output.json", "w") as file:
    json.dump(tree, file, indent=4)

print("saved json to output.json")
# Out:
# saved json to output.json

# %% [markdown]
# ## Task 3: Code Churn Analysis
#
# The third and last task is to analyze the code churn of the _elasticsearch_ project. For this analysis we look at the code churn, meaning the daily change in the total number of lines of the project. Visualize the code churn over time bucketing the data by day. Remember that you'll need to interpolate the data for days when there are no commits. Chose an interpolation strategy and justify it.
#
# Look at the churn trend over time and identify two outliers. For each of them:
# - identify if it was caused by a single or multiple commits (since you are bucketing the data by day)
# - find the hash of the involved commit(s)
# - find the involved files
# - look at the actual diff
#
# Based on the above, discuss if the outlier is a false positive or should be a reason for concern.

# %%
from tqdm import tqdm
import pydriller

repo = pydriller.Repository("elasticsearch",
                            from_tag="v0.90.0",
                            to_tag="v1.0.0.RC1")

# bucketing commits by day
day_to_num_commits = {}
for commit in tqdm(repo.traverse_commits()):
    day = commit.committer_date.date()
    if day not in day_to_num_commits:
        day_to_num_commits[day] = {"added": 0, "removed": 0, "commits": 0}
    
    day_to_num_commits[day]["commits"] += 1
    for file in commit.modified_files:
        day_to_num_commits[day]["added"] += file.added_lines
        day_to_num_commits[day]["removed"] += file.deleted_lines
# Out:
# 1934it [01:17, 24.91it/s]

# %% [markdown]
# #### Choosing an interpolation strategy:
# On the days where there were no commits, we decided to fill the associated values (ie lines added, lines removed, number of commits) with zeroes. Since we are bucketing commits by day, an interpolation strategy that somehow combines values from previous and subsequent days would not make sense, since we know missing dates in the data to mean that no commits were made that day. Putting anything other than zero for the values on those days would be inaccurate.

# %%
from bokeh.plotting import figure, show
import pandas as pd
from bokeh.models import ColumnDataSource, HoverTool, LabelSet

# interpolating and afterwards plotting the data
df = pd.DataFrame.from_dict(day_to_num_commits, orient="index").reset_index()
df.columns = ["day","added", "removed", "commits"]

# applying interpolation strategy
all_days = pd.date_range(df["day"].min(), df["day"].max(), freq="D")
# filling days w/o commits with zeroes
df = (
    df.set_index("day")
      .reindex(all_days)
      .fillna(0)
      .rename_axis("day")
      .reset_index()
)

# plotting with bokeh
changes = ["added", "removed"]
source = ColumnDataSource(df)
colors = ["#a8e6cf", "#ff8b94"]

p = figure(
    x_axis_type="datetime",
    title="Code Churn in the Elasticsearch Repository",
    width=1400,
    height=600,
)

DAY = 24 * 60 * 60 * 1000

renderers = p.vbar_stack(
    changes,
    x="day",
    width=0.8 * DAY,             
    source=source,
    legend_label=changes,
    color=colors,
)

p.legend.items = list(reversed(p.legend.items))

tools = HoverTool(
    renderers=[renderers[1]],
    tooltips = [
        ("Date", "@day{%F}"),
        ("Removed", "@removed"),
        ("Added", "@added"),
        ("Commits", "@commits")
        ],
    formatters={
        '@day': 'datetime'},
    mode = 'vline',
)

p.add_tools(tools)

show(p)

# %% [markdown]
# #### Identifying Two Outliers
#
# Running the code in the cell above renders the following interactive bokeh plot:
#
# ![image](images/code_churn.png)
#
# We identify the following two outliers:
# * Outlier #1: January 7th, 2014 --> 27,790 lines added and 25,224 lines removed over 20 commits
#
# * Outlier #2: November 24th, 2013 --> 28,692 lines added and 1,410 lines removed over 5 commits
#
# We will not analyze the commits on these days more thoroughly:

# %%
print("OUTLIER #1: 07.01.2014 - 27,790 lines added & 25,224 lines removed over 20 commits")
print("Hashes of the involved commits:")
i=1
for commit in repo.traverse_commits():
    if commit.committer_date.date() == pd.to_datetime("2014-01-07").date():
        message = commit.msg.splitlines()
        print(f"{i})\tHash: {commit.hash}\n\tInvolved files: {[file.filename for file in commit.modified_files]}\n\
        Lines added: {sum([file.added_lines for file in commit.modified_files])}\n\
        Lines removed: {sum([file.deleted_lines for file in commit.modified_files])}")
        print('\tCommit Message:\n\t\"')
        for line in message:
            if line.strip() != "":
                print(f"\t{line.strip()}")
        print('\t"\n')
        i+=1
    
print("\nOUTLIER #2: 24.11.2013 - 28,692 lines added & 1,410 lines removed over 5 commits")
print("Hashes of the involved commits:")
i=1
for commit in repo.traverse_commits():
    if commit.committer_date.date() == pd.to_datetime("2013-11-24").date():
        message = commit.msg.splitlines()
        print(f"{i})\tHash: {commit.hash}\n\tInvolved files: {[file.filename for file in commit.modified_files]}\n\
        Lines added: {sum([file.added_lines for file in commit.modified_files])}\n\
        Lines removed: {sum([file.deleted_lines for file in commit.modified_files])}")
        print('\tCommit Message:\n\t\"')
        for line in message:
            if line.strip() != "":
                print(f"\t{line.strip()}")
        print('\t"\n')
        i+=1
# Out:
# OUTLIER #1: 07.01.2014 - 27,790 lines added & 25,224 lines removed over 20 commits
# Hashes of the involved commits:
# 1)	Hash: 8d9af7e7a5c69205ae840a2722900dc8a1c60475
# 	Involved files: ['build_release.py']
#         Lines added: 2
#         Lines removed: 2
# 	Commit Message:
# 	"
# 	Start elasticsearch as deamon when running smoketests
# 	In previous version daemonized was default now we need to set it explicitly.
# 	"
#
# 2)	Hash: fa16969360ea43667ad11f827bbf86718c18fcc6
# 	Involved files: ['NOTICE.txt', 'README.textile', 'elasticsearch', 'elasticsearch.bat', 'service.bat', 'elasticsearch.yml', 'clients.asciidoc', 'frontends.asciidoc', 'integrations.asciidoc', 'misc.asciidoc', 'monitoring.asciidoc', 'anatomy.asciidoc', 'bulk.asciidoc', 'index_.asciidoc', 'get.asciidoc', 'index_.asciidoc', 'mapper.asciidoc', 'store.asciidoc', 'create-index.asciidoc', 'flush.asciidoc', 'mapping.asciidoc', 'geo-shape-type.asciidoc', 'object-type.asciidoc', 'discovery.asciidoc', 'fs.asciidoc', 'plugins.asciidoc', 'transport.asciidoc', 'search.asciidoc', 'facets.asciidoc', 'request-body.asciidoc', 'search-type.asciidoc', 'uri-request.asciidoc', 'validate.asciidoc', 'setup.asciidoc', 'configuration.asciidoc', 'pom.xml', 'control', 'elasticsearch', 'elasticsearch', 'StoreRateLimiting.java', 'ElasticsearchException.java', 'ElasticsearchGenerationException.java', 'ElasticsearchIllegalArgumentException.java', 'ElasticsearchIllegalStateException.java', 'ElasticsearchInterruptedException.java', 'ElasticsearchNullPointerException.java', 'ElasticsearchParseException.java', 'ElasticsearchTimeoutException.java', 'ElasticsearchWrapperException.java', 'ExceptionsHelper.java', 'ActionFuture.java', 'ActionRequestBuilder.java', 'ActionRequestValidationException.java', 'FailedNodeException.java', 'PrimaryMissingActionException.java', 'RoutingMissingException.java', 'ThreadingModel.java', 'TimestampParsingException.java', 'TransportActionNodeProxy.java', 'UnavailableShardsException.java', 'WriteConsistencyLevel.java', 'ClusterHealthStatus.java', 'TransportClusterHealthAction.java', 'TransportNodesHotThreadsAction.java', 'TransportNodesInfoAction.java', 'TransportNodesRestartAction.java', 'TransportNodesShutdownAction.java', 'TransportNodesStatsAction.java', 'TransportDeleteRepositoryAction.java', 'TransportGetRepositoriesAction.java', 'PutRepositoryRequest.java', 'TransportPutRepositoryAction.java', 'ClusterRerouteRequest.java', 'TransportClusterRerouteAction.java', 'ClusterUpdateSettingsRequest.java', 'TransportClusterUpdateSettingsAction.java', 'ClusterSearchShardsRequest.java', 'TransportClusterSearchShardsAction.java', 'CreateSnapshotRequest.java', 'TransportCreateSnapshotAction.java', 'TransportDeleteSnapshotAction.java', 'TransportGetSnapshotsAction.java', 'RestoreSnapshotRequest.java', 'TransportRestoreSnapshotAction.java', 'TransportClusterStateAction.java', 'TransportClusterStatsAction.java', 'TransportPendingClusterTasksAction.java', 'IndicesAliasesRequest.java', 'TransportIndicesAliasesAction.java', 'TransportAliasesExistAction.java', 'TransportGetAliasesAction.java', 'TransportAnalyzeAction.java', 'TransportClearIndicesCacheAction.java', 'TransportCloseIndexAction.java', 'CreateIndexRequest.java', 'TransportCreateIndexAction.java', 'TransportDeleteIndexAction.java', 'TransportIndicesExistsAction.java', 'TransportTypesExistsAction.java', 'FlushRequest.java', 'TransportFlushAction.java', 'TransportGatewaySnapshotAction.java', 'TransportDeleteMappingAction.java', 'TransportGetFieldMappingsAction.java', 'TransportGetMappingsAction.java', 'PutMappingRequest.java', 'TransportPutMappingAction.java', 'TransportOpenIndexAction.java', 'TransportOptimizeAction.java', 'TransportRefreshAction.java', 'TransportIndicesSegmentsAction.java', 'TransportUpdateSettingsAction.java', 'UpdateSettingsRequest.java', 'TransportIndicesStatsAction.java', 'GatewayRecoveryStatus.java', 'GatewaySnapshotStatus.java', 'PeerRecoveryStatus.java', 'TransportIndicesStatusAction.java', 'TransportDeleteIndexTemplateAction.java', 'TransportGetIndexTemplatesAction.java', 'PutIndexTemplateRequest.java', 'TransportPutIndexTemplateAction.java', 'TransportValidateQueryAction.java', 'ValidateQueryRequest.java', 'TransportDeleteWarmerAction.java', 'TransportGetWarmersAction.java', 'TransportPutWarmerAction.java', 'BulkProcessor.java', 'BulkRequest.java', 'TransportShardBulkAction.java', 'CountRequest.java', 'TransportCountAction.java', 'TransportShardDeleteAction.java' ...
#         Lines added: 2381
#         Lines removed: 2409
# 	Commit Message:
# 	"
# 	Cleanup comments and class names s/ElasticSearch/Elasticsearch
# 	* Clean up s/ElasticSearch/Elasticsearch on docs/*
# 	* Clean up s/ElasticSearch/Elasticsearch on src/* bin/* & pom.xml
# 	* Clean up s/ElasticSearch/Elasticsearch on NOTICE.txt and README.textile
# 	Closes #4634
# 	"
#
# 3)	Hash: 10ec2e948a2f1426a5058ca3b2c2e39952f141d8
# 	Involved files: ['NOTICE.txt', 'README.textile', 'ElasticSearch.launch', 'build_randomization.rb', 'build_release.py', 'client_tests_urls.prop', 'upload-s3.py', 'CustomAnalyzerWrapper.java', 'TruncateTokenFilter.java', 'UniqueTokenFilter.java', 'TrackingConcurrentMergeScheduler.java', 'TrackingSerialMergeScheduler.java', 'ExtendedMemoryIndex.java', 'ExtendedCommonTermsQuery.java', 'ExistsFieldQueryExtension.java', 'FieldQueryExtension.java', 'MapperQueryParser.java', 'MissingFieldQueryExtension.java', 'QueryParserSettings.java', 'CustomPassageFormatter.java', 'CustomPostingsHighlighter.java', 'Snippet.java', 'XPostingsHighlighter.java', 'XAnalyzingSuggester.java', 'XFuzzySuggester.java', 'CustomFieldQuery.java', 'RateLimitedFSDirectory.java', 'StoreRateLimiting.java', 'StoreUtils.java', 'Build.java', 'ElasticsearchException.java', 'ElasticsearchGenerationException.java', 'ElasticsearchIllegalArgumentException.java', 'ElasticsearchIllegalStateException.java', 'ElasticsearchInterruptedException.java', 'ElasticsearchNullPointerException.java', 'ElasticsearchParseException.java', 'ElasticsearchTimeoutException.java', 'ElasticsearchWrapperException.java', 'ExceptionsHelper.java', 'Version.java', 'Action.java', 'ActionFuture.java', 'ActionListener.java', 'ActionModule.java', 'ActionRequest.java', 'ActionRequestBuilder.java', 'ActionRequestValidationException.java', 'ActionResponse.java', 'FailedNodeException.java', 'GenericAction.java', 'ListenableActionFuture.java', 'NoShardAvailableActionException.java', 'NoSuchNodeException.java', 'PrimaryMissingActionException.java', 'RoutingMissingException.java', 'ShardOperationFailedException.java', 'ThreadingModel.java', 'TimestampParsingException.java', 'TransportActionNodeProxy.java', 'UnavailableShardsException.java', 'ValidateActions.java', 'WriteConsistencyLevel.java', 'ClusterAction.java', 'ClusterHealthAction.java', 'ClusterHealthRequest.java', 'ClusterHealthRequestBuilder.java', 'ClusterHealthResponse.java', 'ClusterHealthStatus.java', 'ClusterIndexHealth.java', 'ClusterShardHealth.java', 'TransportClusterHealthAction.java', 'NodeHotThreads.java', 'NodesHotThreadsAction.java', 'NodesHotThreadsRequest.java', 'NodesHotThreadsRequestBuilder.java', 'NodesHotThreadsResponse.java', 'TransportNodesHotThreadsAction.java', 'NodeInfo.java', 'NodesInfoAction.java', 'NodesInfoRequest.java', 'NodesInfoRequestBuilder.java', 'NodesInfoResponse.java', 'TransportNodesInfoAction.java', 'NodesRestartAction.java', 'NodesRestartRequest.java', 'NodesRestartRequestBuilder.java', 'NodesRestartResponse.java', 'TransportNodesRestartAction.java', 'NodesShutdownAction.java', 'NodesShutdownRequest.java', 'NodesShutdownRequestBuilder.java', 'NodesShutdownResponse.java', 'TransportNodesShutdownAction.java', 'NodeStats.java', 'NodesStatsAction.java', 'NodesStatsRequest.java', 'NodesStatsRequestBuilder.java', 'NodesStatsResponse.java', 'TransportNodesStatsAction.java', 'DeleteRepositoryAction.java', 'DeleteRepositoryRequest.java', 'DeleteRepositoryRequestBuilder.java', 'DeleteRepositoryResponse.java', 'TransportDeleteRepositoryAction.java', 'GetRepositoriesAction.java', 'GetRepositoriesRequest.java', 'GetRepositoriesRequestBuilder.java', 'GetRepositoriesResponse.java', 'TransportGetRepositoriesAction.java', 'PutRepositoryAction.java', 'PutRepositoryRequest.java', 'PutRepositoryRequestBuilder.java', 'PutRepositoryResponse.java', 'TransportPutRepositoryAction.java', 'ClusterRerouteAction.java', 'ClusterRerouteRequest.java', 'ClusterRerouteRequestBuilder.java', 'ClusterRerouteResponse.java', 'TransportClusterRerouteAction.java', 'ClusterUpdateSettingsAction.java', 'ClusterUpdateSettingsRequest.java', 'ClusterUpdateSettingsRequestBuilder.java', 'ClusterUpdateSettingsResponse.java', 'TransportClusterUpdateSettingsAction.java', 'ClusterSearchShardsAction.java', 'ClusterSearchShardsGroup.java', 'ClusterSearchShardsRequest.java', 'ClusterSearchShardsRequestBuilder.java', 'ClusterSearchShardsResponse.java', 'TransportCluste ...
#         Lines added: 21846
#         Lines removed: 21839
# 	Commit Message:
# 	"
# 	Fix ASL Header in source files to reflect s/ElasticSearch/Elasticsearch
# 	This commit also removes the license to Shay Banon in favor of soley
# 	Elasticsearch. Thanks Shay for this awesome product you took it far!
# 	Closes #4636
# 	"
#
# 4)	Hash: a4b2366e1e50953b7308b21963133dc50dd3fc60
# 	Involved files: ['PluginInfo.java', 'PluginsInfo.java', 'PercolateShardRequest.java', 'MultiSearchResponse.java', 'ElasticsearchF.java', 'EmptyClusterInfoService.java', 'BlobStore.java', 'SpatialStrategy.java', 'AdapterStreamInput.java', 'ByteBufferStreamInput.java', 'KeepFrameDecoder.java', 'NettyStaticSetup.java', 'SettingsFilter.java', 'UTF8SortedAsUnicodeComparator.java', 'AnalysisSettingsRequired.java', 'CzechStemTokenFilterFactory.java', 'QueriesLoaderCollector.java', 'PercolateStats.java', 'BoostableQueryBuilder.java', 'ParsedFilter.java', 'IncludeNestedDocsQuery.java', 'BufferingFsTranslogFile.java', 'RestGetIndicesAliasesAction.java', 'AbstractAggregationBuilder.java', 'AggregationBuilder.java', 'AggregationBuilders.java', 'ValuesSourceAggregationBuilder.java', 'FilterAggregationBuilder.java', 'GlobalBuilder.java', 'DateHistogramBuilder.java', 'HistogramBuilder.java', 'MissingBuilder.java', 'NestedBuilder.java', 'AbstractRangeBuilder.java', 'RangeBuilder.java', 'DateRangeBuilder.java', 'GeoDistanceBuilder.java', 'IPv4RangeBuilder.java', 'TermsBuilder.java', 'MetricsAggregationBuilder.java', 'ValuesSourceMetricsAggregationBuilder.java', 'AvgBuilder.java', 'MaxBuilder.java', 'MinBuilder.java', 'StatsBuilder.java', 'ExtendedStatsBuilder.java', 'SumBuilder.java', 'ValueCountBuilder.java', 'ScriptValueType.java', 'Suggester.java', 'ChannelBufferStreamInputFactory.java', 'SizeHeaderFrameDecoder.java', 'BloomBench.java', 'NativeScriptExamplesPlugin.java', 'NativeConstantForLoopScoreScript.java', 'NativeConstantScoreScript.java', 'NativeNaiveTFIDFScoreScript.java', 'NativePayloadSumNoRecordScoreScript.java', 'NativePayloadSumScoreScript.java', 'NestedSearchBenchMark.java', 'AddIncrementallyTests.java', 'SameShardRoutingTests.java', 'UpdateNumberOfReplicasTests.java', 'ClusterStateToStringTests.java', 'DateMathParserTests.java', 'XBooleanFilterLuceneTests.java', 'XBooleanFilterTests.java', 'SimpleCountTests.java', 'BulkTests.java', 'DoubleIndexingDocTest.java', 'StoredNumericValuesTest.java', 'TTLMappingTests.java', 'UpdateMappingTests.java', 'TTLPercolatorTests.java', 'ExtendedFacetsTests.java', 'ExtendedFacetsTestsMultiShardMultiNodeTests.java', 'SimpleMultiSearchTests.java', 'ConcurrentSearchSerializationTests.java', 'ReproduceInfoPrinter.java', 'SimpleThreadPoolTests.java', 'ConcurrentDocumentOperationTests.java']
#         Lines added: 1469
#         Lines removed: 15
# 	Commit Message:
# 	"
# 	Add missing license headers
# 	"
#
# 5)	Hash: 1ddc0493dfb3c9aab318792d0f498974deddb866
# 	Involved files: ['BytesRefComparisonsBenchmark.java']
#         Lines added: 140
#         Lines removed: 0
# 	Commit Message:
# 	"
# 	Add a benchmark for BytesRef comparisons.
# 	"
#
# 6)	Hash: 3413eedd8dcfd84e138ae34388c4ce5e5909c02a
# 	Involved files: ['BytesRefComparisonsBenchmark.java']
#         Lines added: 7
#         Lines removed: 7
# 	Commit Message:
# 	"
# 	Fix license header og BytesRefComparisonsBenchmark.
# 	"
#
# 7)	Hash: b9714eae60e4f56742e94e69d8cb52e769c53285
# 	Involved files: ['org.eclipse.jdt.ui.prefs']
#         Lines added: 1
#         Lines removed: 1
# 	Commit Message:
# 	"
# 	Update Eclipse template to use the new license header.
# 	"
#
# 8)	Hash: 107ae66a6020c5ff940a862f642feadd601d980e
# 	Involved files: ['RecyclerUtils.java', 'ChildrenConstantScoreQuery.java', 'ChildrenQuery.java', 'ParentConstantScoreQuery.java', 'ParentQuery.java', 'TopChildrenQuery.java']
#         Lines added: 12
#         Lines removed: 63
# 	Commit Message:
# 	"
# 	Replace RecyclerUtils with Releasables.
# 	"
#
# 9)	Hash: 4aeaa3bac4662e866703793dfdf4d433d257bea1
# 	Involved files: ['20_fields.yaml', '70_source_filtering.yaml', '10_basic.yaml', '20_fields.yaml', '20_fields_pre_0.90.3.yaml', '10_source_filtering.yaml', '40_routing.yaml', '50_parent.yaml', '55_parent_with_routing.yaml', '80_fields.yaml']
#         Lines added: 43
#         Lines removed: 43
# 	Commit Message:
# 	"
# 	[TEST] Fix yaml tests after #4542
# 	"
#
# 10)	Hash: 623e4a0fc887b7d1cabfe8cc8496cb22eda2fbcd
# 	Involved files: ['40_parent.yaml', '10_basic.yaml', '30_parent.yaml', '55_parent_with_routing.yaml', '20_source_filtering.yaml', '30_parent.yaml', '70_source_filtering.yaml', '10_basic.yaml', '15_default_values.yaml', '30_parent.yaml', '40_routing.yaml', '55_parent_with_routing.yaml', '60_realtime_refresh.yaml', '70_source_filtering.yaml', '80_missing.yaml', '20_analyze_text_format.yaml', '10_basic.yaml', '10_basic.yaml', '20_missing_field.yaml', '30_missing_type.yaml', '40_missing_index.yaml', '50_field_wildcards.yaml', '10_basic.yaml', '10_basic.yaml', '20_get_missing.yaml', '10_basic.yaml', '10_basic.yaml', '20_lucene_version.yaml', '12_non_existent_index.yaml', '20_fields.yaml', '20_fields_pre_0.90.3.yaml', '30_parent.yaml', '55_parent_with_routing.yaml', '70_source_filtering.yaml', '10_old.yaml', '15_new.yaml', '10_source_filtering.yaml', '10_basic.yaml', '22_doc_as_upsert.yaml', '30_internal_version.yaml', '35_external_version.yaml', '50_parent.yaml']
#         Lines added: 12
#         Lines removed: 518
# 	Commit Message:
# 	"
# 	[TEST] remove old tests from yaml test suite
# 	"
#
# 11)	Hash: 7166ab6b6f9b7ded3784d84d57c2e846a66fc923
# 	Involved files: ['MatchAssertion.java']
#         Lines added: 3
#         Lines removed: 3
# 	Commit Message:
# 	"
# 	Fixed match assertion that didn't run any assert with object of different types that don't extend Number
# 	"
#
# 12)	Hash: d23f640cd1488727c8337a888527d662c6135fac
# 	Involved files: ['10_basic.yaml', '10_basic.yaml', '10_with_id.yaml', '15_without_id.yaml', '10_basic.yaml', '10_basic.yaml', '10_basic.yaml', '10_with_id.yaml', '15_without_id.yaml', '10_basic.yaml', '10_basic.yaml', '10_basic.yaml', '10_basic.yaml', '10_basic.yaml', '10_basic.yaml', '10_basic.yaml', '10_basic.yaml', '10_basic.yaml', '10_basic.yaml', '10_info.yaml', 'AcknowledgedRestResponseActionListener.java', 'RestNodesInfoAction.java', 'RestClusterSearchShardsAction.java', 'RestClearIndicesCacheAction.java', 'RestFlushAction.java', 'RestGatewaySnapshotAction.java', 'RestOptimizeAction.java', 'RestRefreshAction.java', 'RestIndicesSegmentsAction.java', 'RestIndicesStatsAction.java', 'RestIndicesStatusAction.java', 'RestBulkAction.java', 'RestDeleteAction.java', 'RestDeleteByQueryAction.java', 'RestExplainAction.java', 'RestIndexAction.java', 'RestMainAction.java', 'RestClearScrollAction.java', 'RestUpdateAction.java', 'RiversService.java', 'TestSectionParserTests.java']
#         Lines added: 5
#         Lines removed: 81
# 	Commit Message:
# 	"
# 	Remove hard-coded "ok": true from REST responses
# 	"
#
# 13)	Hash: 2cb40fcb1741ce1bf4c770aeec8b85717f2b5d98
# 	Involved files: ['termvectors.asciidoc', '60_realtime_refresh.yaml', '10_basic.yaml', '11_default_index_type.yaml', '12_non_existent_index.yaml', '13_missing_metadata.yaml', '15_ids.yaml', '30_parent.yaml', '40_routing.yaml', '55_parent_with_routing.yaml', '60_realtime_refresh.yaml', 'TransportShardBulkAction.java', 'DeleteResponse.java', 'TransportDeleteAction.java', 'ShardDeleteResponse.java', 'TransportShardDeleteAction.java', 'TermVectorResponse.java', 'Engine.java', 'RobinEngine.java', 'GetResult.java', 'RestBulkAction.java', 'RestDeleteAction.java', 'RestIndexAction.java', 'GetTermVectorCheckDocFreqTests.java', 'GetActionTests.java', 'SimpleNestedTests.java', 'ConcurrentPercolatorTests.java', 'SimpleVersioningTests.java']
#         Lines added: 85
#         Lines removed: 92
# 	Commit Message:
# 	"
# 	Rename "exists" to "found" in TermVector and Get responses
# 	- Adds the "created" field to the index action response
# 	- Reverses Delete class' notFound to Found to avoid double negative
# 	"
#
# 14)	Hash: abf68c472e64cf159f26166e9586dde5d4047a94
# 	Involved files: ['TranslogService.java']
#         Lines added: 6
#         Lines removed: 1
# 	Commit Message:
# 	"
# 	don't schedule a flush if there are no operations in the translog
# 	this can happen with the 30m time base setting expires
# 	"
#
# 15)	Hash: 602de046922a42e7f85d0da060cfb784eb863d68
# 	Involved files: ['bucket.asciidoc', 'geohashgrid-aggregation.asciidoc', 'GeoHashUtils.java', 'AggregationBuilders.java', 'AggregationModule.java', 'TransportAggregationModule.java', 'BucketUtils.java', 'GeoHashGrid.java', 'GeoHashGridAggregator.java', 'GeoHashGridBuilder.java', 'GeoHashGridParser.java', 'InternalGeoHashGrid.java', 'GeoHashTests.java', 'GeoHashGridTests.java']
#         Lines added: 1432
#         Lines removed: 16
# 	Commit Message:
# 	"
# 	A GeoHashGrid aggregation that buckets GeoPoints into cells whose dimensions are determined by a choice of GeoHash resolution.
# 	Added a long-based representation of GeoHashes to GeoHashUtils for fast evaluation in aggregations.
# 	The new BucketUtils provides a common heuristic for determining the number of results to obtain from each shard in "top N" type requests.
# 	"
#
# 16)	Hash: 4aa5ef139e3429bec892693ab8259a768779a63b
# 	Involved files: ['translog.asciidoc', 'IndexDynamicSettingsModule.java', 'TranslogService.java']
#         Lines added: 24
#         Lines removed: 17
# 	Commit Message:
# 	"
# 	randomize flush interval so multiple shards won't flush at the sam time
# 	- also, allow to update interval using update settings on an index
# 	"
#
# 17)	Hash: 5d98341d11311bca0e468db3978be311855a3a3d
# 	Involved files: ['snapshots.asciidoc']
#         Lines added: 1
#         Lines removed: 1
# 	Commit Message:
# 	"
# 	Fix typo in snapshot/restore documentation
# 	"
#
# 18)	Hash: 2b49ec138c9b0ce465f9aa1275cad098bca6ae14
# 	Involved files: ['SnapshotInfo.java']
#         Lines added: 1
#         Lines removed: 2
# 	Commit Message:
# 	"
# 	Fix mixed up duration and duration_in_millis fields in snapshot information output
# 	"
#
# 19)	Hash: b9aaa79afdd9a4d9290167745925985fa982892e
# 	Involved files: ['ExtendedMemoryIndex.java', 'ExtendedCommonTermsQuery.java', 'ClusterStatsIndices.java', 'ClusterStatsNodes.java', 'MultiTermVectorsRequest.java', 'MultiTermVectorsRequestBuilder.java', 'UpdateHelper.java', 'HppcMaps.java', 'DateMathParser.java', 'CJKBigramFilterFactory.java', 'CJKWidthFilterFactory.java', 'KeepWordFilterFactory.java', 'AbstractIndexFieldData.java', 'DoubleValuesComparatorBase.java', 'LongValuesComparatorBase.java', 'PercolatorQueriesRegistry.java', 'SimpleQueryStringFlag.java', 'PercolateException.java', 'QueryRescorer.java', 'Rescorer.java', 'ScanContext.java', 'PayloadProcessor.java', 'SnapshotShardFailure.java', 'SnapshotState.java', 'BaseDateTime.java', 'ClusterStatsTests.java', 'AbstractTermVectorTests.java', 'MultiTermVectorsTests.java', 'TransportClientTests.java', 'ClusterHealthResponsesTests.java', 'ShardsAllocatorModuleTests.java', 'BooleansTests.java', 'XContentHelperTests.java', 'VersionTypeTests.java', 'SourceFetchingTests.java', 'NoisyChannelSpellCheckerTests.java']
#         Lines added: 318
#         Lines removed: 112
# 	Commit Message:
# 	"
# 	Add missing license headers, move package names after  license headers
# 	"
#
# 20)	Hash: 3cffe334ba6c2be9434c962c6944e74cf31df014
# 	Involved files: ['client_tests_urls.prop']
#         Lines added: 2
#         Lines removed: 2
# 	Commit Message:
# 	"
# 	change url to latest snapshops
# 	"
#
#
# OUTLIER #2: 24.11.2013 - 28,692 lines added & 1,410 lines removed over 5 commits
# Hashes of the involved commits:
# 1)	Hash: c7f6c5266d15fefa1a5ce9ae7ffc519c5ff8abbe
# 	Involved files: ['search.asciidoc', 'aggregations.asciidoc', 'bucket.asciidoc', 'datehistogram-aggregation.asciidoc', 'daterange-aggregation.asciidoc', 'filter-aggregation.asciidoc', 'geodistance-aggregation.asciidoc', 'global-aggregation.asciidoc', 'histogram-aggregation.asciidoc', 'iprange-aggregation.asciidoc', 'missing-aggregation.asciidoc', 'nested-aggregation.asciidoc', 'range-aggregation.asciidoc', 'terms-aggregation.asciidoc', 'metrics.asciidoc', 'avg-aggregation.asciidoc', 'extendedstats-aggregation.asciidoc', 'max-aggregation.asciidoc', 'min-aggregation.asciidoc', 'stats-aggregation.asciidoc', 'sum-aggregation.asciidoc', 'SearchRequestBuilder.java', 'SearchResponse.java', 'TransportSearchScrollScanAction.java', 'CompressedIndexInput.java', 'GeoPoint.java', 'TimeZoneRounding.java', 'ReaderContextAware.java', 'ScorerAware.java', 'DateTimeUnit.java', 'Rounding.java', 'TimeZoneRounding.java', 'TimeValue.java', 'BigArray.java', 'BigArrays.java', 'BigDoubleArray.java', 'BigIntArray.java', 'BigLongArray.java', 'BigObjectArray.java', 'DoubleArray.java', 'IntArray.java', 'IntArrays.java', 'LongArray.java', 'ObjectArray.java', 'XContentBuilder.java', 'FSTBytesAtomicFieldData.java', 'PagedBytesAtomicFieldData.java', 'SortedSetDVAtomicFieldData.java', 'DateFieldMapper.java', 'PercolateContext.java', 'SearchScript.java', 'MvelScriptEngineService.java', 'SearchModule.java', 'TransportSearchModule.java', 'AbstractAggregationBuilder.java', 'Aggregation.java', 'AggregationBinaryParseElement.java', 'AggregationBuilder.java', 'AggregationBuilders.java', 'AggregationExecutionException.java', 'AggregationInitializationException.java', 'AggregationModule.java', 'AggregationParseElement.java', 'AggregationPhase.java', 'AggregationStreams.java', 'Aggregations.java', 'Aggregator.java', 'AggregatorFactories.java', 'AggregatorFactory.java', 'AggregatorParsers.java', 'InternalAggregation.java', 'InternalAggregations.java', 'SearchContextAggregations.java', 'TransportAggregationModule.java', 'ValuesSourceAggregationBuilder.java', 'Bucket.java', 'BucketsAggregator.java', 'LongHash.java', 'SingleBucketAggregation.java', 'SingleBucketAggregator.java', 'Filter.java', 'FilterAggregationBuilder.java', 'FilterAggregator.java', 'FilterParser.java', 'InternalFilter.java', 'Global.java', 'GlobalAggregator.java', 'GlobalBuilder.java', 'GlobalParser.java', 'InternalGlobal.java', 'AbstractHistogramBase.java', 'DateHistogram.java', 'DateHistogramBuilder.java', 'DateHistogramParser.java', 'Histogram.java', 'HistogramAggregator.java', 'HistogramBase.java', 'HistogramBuilder.java', 'HistogramParser.java', 'InternalDateHistogram.java', 'InternalHistogram.java', 'InternalOrder.java', 'InternalMissing.java', 'Missing.java', 'MissingAggregator.java', 'MissingBuilder.java', 'MissingParser.java', 'InternalNested.java', 'Nested.java', 'NestedAggregator.java', 'NestedBuilder.java', 'NestedParser.java', 'AbstractRangeBase.java', 'InternalRange.java', 'Range.java', 'RangeAggregator.java', 'RangeBase.java', 'RangeBuilder.java', 'RangeBuilderBase.java', 'RangeParser.java', 'DateRange.java', 'DateRangeBuilder.java', 'DateRangeParser.java', 'InternalDateRange.java', 'GeoDistance.java', 'GeoDistanceBuilder.java', 'GeoDistanceParser.java', 'InternalGeoDistance.java', 'IPv4Range.java', 'IPv4RangeBuilder.java', 'InternalIPv4Range.java', 'IpRangeParser.java', 'BucketPriorityQueue.java', 'DoubleTerms.java', 'DoubleTermsAggregator.java', 'InternalOrder.java', 'InternalTerms.java', 'LongTerms.java', 'LongTermsAggregator.java', 'StringTerms.java', 'StringTermsAggregator.java', 'Terms.java', 'TermsAggregatorFactory.java', 'TermsBuilder.java', 'TermsParser.java', 'UnmappedTerms.java', 'UnmappedTermsAggregator.java', 'MetricsAggregation.java', 'MetricsAggregationBuilder.java', 'ValuesSourceMetricsAggregationBuilder.java', 'ValuesSourceMetricsAggregatorParser.java', 'Avg.java', 'AvgAggregator.java', 'AvgBuilder.java', 'AvgParser.java', 'InternalAvg.java', 'InternalMax.java', 'Max.java',  ...
#         Lines added: 28385
#         Lines removed: 734
# 	Commit Message:
# 	"
# 	initial commit of the aggregations module
# 	Closes #3300
# 	"
#
# 2)	Hash: 8fda8aaabfa2e99e140093d8949fdf9fc72605be
# 	Involved files: ['ChildrenConstantScoreQueryTests.java', 'ChildrenQueryTests.java', 'ParentConstantScoreQueryTests.java', 'ParentQueryTests.java']
#         Lines added: 40
#         Lines removed: 8
# 	Commit Message:
# 	"
# 	force default codec
# 	reduce p/c searches and num child docs being generated
# 	"
#
# 3)	Hash: 28adbd475dbaa9ef689cabcc501004f05b74a8b7
# 	Involved files: ['MissingTests.java']
#         Lines added: 4
#         Lines removed: 0
# 	Commit Message:
# 	"
# 	added a waitForGreen condition for the unmapped tests on missing agg
# 	"
#
# 4)	Hash: 8e17d636ef441a9be80977d34acfaabc12982eb7
# 	Involved files: ['pom.xml', 'XIndexWriter.java', 'MapperQueryParser.java', 'XLuceneConstantScoreQuery.java', 'CustomPassageFormatter.java', 'CustomPostingsHighlighter.java', 'XDefaultPassageFormatter.java', 'XPassageFormatter.java', 'XPostingsHighlighter.java', 'XAnalyzingSuggester.java', 'RateLimitedFSDirectory.java', 'ByteBufferDirectory.java', 'Version.java', 'TermVectorFields.java', 'Lucene.java', 'XConstantScoreQuery.java', 'XFilteredQuery.java', 'SynonymTokenFilterFactory.java', 'PerFieldMappingPostingFormatCodec.java', 'BloomFilterPostingsFormat.java', 'RobinEngine.java', 'IdFieldMapper.java', 'ParentFieldMapper.java', 'OnGoingMerge.java', 'IndexUpgraderMergePolicy.java', 'CommonTermsQueryParser.java', 'ConstantScoreQueryParser.java', 'IdsQueryParser.java', 'Store.java', 'QueryFacetExecutor.java', 'CustomPostingsHighlighterTests.java', 'XPostingsHighlighterTests.java', 'FilterCacheTests.java', 'CodecTests.java', 'DefaultPostingsFormatTests.java', 'SimpleIndexQueryParserTests.java', 'CompletionPostingsFormatTest.java', 'NoisyChannelSpellCheckerTests.java']
#         Lines added: 118
#         Lines removed: 667
# 	Commit Message:
# 	"
# 	Upgrade to Lucene 4.6
# 	This commit upgrades to Lucene 4.6 and contains the following improvements:
# 	* Remove XIndexWriter in favor of the fixed IndexWriter
# 	* Removes patched XLuceneConstantScoreQuery
# 	* Now uses Lucene passage formatters contributed from Elasticsearch in PostingsHighlighter
# 	* Upgrades to Lucene46 Codec from Lucene45 Codec
# 	* Fixes problem in CommonTermsQueryParser where close was never called.
# 	Closes #4241
# 	"
#
# 5)	Hash: e3d4d73242d215389280b1d7b9facb7b1bd9bd7d
# 	Involved files: ['ThrottlingAllocationDecider.java', 'PreferLocalPrimariesToRelocatingPrimariesTests.java', 'RoutingAllocationTests.java']
#         Lines added: 145
#         Lines removed: 1
# 	Commit Message:
# 	"
# 	Local primaries should be preferred to relocating primaries
# 	To reproduce the bug use -Dtests.seed=5AB62524C9AB0489
# 	Fixes #4237
# 	"

# %% [markdown]
# #### Validity of the Identified Outliers
# Outlier #1<br>
# This outlier seems to be a false positive. Out of the 20 commits made on this day, the third commit (hash 10ec2e948a2f1426a5058ca3b2c2e39952f141d8) modifies the largest number of lines by far (21,846 lines added, 21,839 lines removed) by changing the license from Shay Bannon to soley Elasticseach. Chaning the license mofidies a lot of lines. Many of the commits following after that also relate to this change of license, fixing small issues with diverse license headers across the repository. As such, it seems like this outlier is not a valid reason for concern and can thus be disregarded.
#
# Outlier #2:<br>
# This outlier is definitely a false positive, i.e. should not be a reason for concern. The first commit made on this day (hash c7f6c5266d15fefa1a5ce9ae7ffc519c5ff8abbe) (out of the daily total of five) added a new module (the aggregations model) to the repository, adding 28,692 lines to the project. The other commits did not modify nearly as many lines. As such, this outlier can be disregarded.
